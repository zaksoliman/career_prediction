# %%
import json
import pandas as pd
import numpy as np
import random
from bidict import bidict
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
from collections import Counter
import re
from pprint import pprint

# %%
# %matplotlib inline

# %%
sns.set(style="darkgrid", color_codes=True)
plt.style.use('ggplot')

# %%
raw_df = pd.read_pickle('/data/rali7/Tmp/solimanz/data/pickles/clean_aug.pkl')

# %%
def fmtcols(mylist, cols):
    maxwidth = max(map(lambda x: len(x), mylist))
    justifyList = list(map(lambda x: x.ljust(maxwidth), mylist))
    lines = (' '.join(justifyList[i:i+cols]) for i in range(0,len(justifyList),cols))
    return "\n".join(lines)

# %%
def apply_transforms(s):
    for transform in transforms:
        s = re.sub(*transform, s)
    return s

# %%
def isEnglish(s):
    try:
        s.encode('ascii')
    except UnicodeEncodeError:
        return False
    else:
        return True

# %%
transforms = [
    # senior/junior
    (re.compile(r'\bsr\.(?=[a-z0-9])'), 'senior '),
    (re.compile(r'\bjr\.(?=[a-z0-9])'), 'junior '),
    (re.compile(r'\bsr\.(?!\S)'), 'senior'),
    (re.compile(r'\bjr\.(?!\S)'), 'junior'),
    (re.compile(r'\bsenior\.(?!\S)'), 'senior'),
    (re.compile(r'\bjunior\.(?!\S)'), 'junior'),
    (re.compile(r'\bsenior\.(?=[a-z0-9])'), 'senior '),
    (re.compile(r'\bjunior\.(?=[a-z0-9])'), 'junior '),
    (re.compile(r'\bsr\b'), 'senior'),
    (re.compile(r'\bjr\b'), 'junior'),
    # IT
    (re.compile(r'\bi\.*t\.*(?=[a-z0-9])'), 'information technology '),
    (re.compile(r'\bi\.*t\.*(?!\S)'), 'information technology'),
    # C*O
    (re.compile(r'\bc\.*e\.*o\.*(?!\S)'), 'chief executive officer'),
    (re.compile(r'\bc\.*o\.*o\.*(?!\S)'), 'chief operating officer'),
    (re.compile(r'\bc\.*t\.*o\.*(?!\S)'), 'chief technology officer'),
    (re.compile(r'\bc\.*f\.*o\.*(?!\S)'), 'chief finance officer'),
    (re.compile(r'\bchief financial officer\b'), 'chief finance officer'),
    (re.compile(r'\bchief operations officer\b'), 'chief operating officer'),
    
    (re.compile(r'\bceo/chief executive officer\b'), 'chief executive officer'),
    (re.compile(r'\bcoo/chief operating officer\b'), 'chief operating officer'),
    (re.compile(r'\bcto/chief technology officer\b'), 'chief technology officer'),
    (re.compile(r'\bcfo/chief finance officer\b'), 'chief finance officer'),
    # VP
    (re.compile(r'\bv\.*p\.(?=[a-z0-9])'), 'vice_president '),
    (re.compile(r'\bv\.*p\.*(?!\S)'), 'vice_president'),
    (re.compile(r'\bvice-president\b'), 'vice_president'),
    (re.compile(r'\bvice president\b'), 'vice_president'),
    #technician vs tech
    (re.compile(r'\btech\.(?=[a-z0-9])'), 'technician '),
    (re.compile(r'\btech\.*(?!\S)'), 'technician'),
    # cofounder
    (re.compile(r'\bco(-|\s)founder\b'), 'co_founder'),
    # co-...
    (re.compile(r'\bco-'), 'co_'),
    #coop
    (re.compile(r'\bco[-|\s]op\b'), 'coop'),
    #addon
    (re.compile(r'\badd[-|\s]on\b'), 'addon'),
    # Nurses
    (re.compile(r'\br\.*n\.*(?!\S)'), 'registered nurse'),
    (re.compile(r'\br\.*n\.(?=[a-z0-9])'), 'registered nurse '),
    (re.compile(r'\br\.*p\.*n\.*(?!\S)'), 'registered practical nurse'),
    (re.compile(r'\br\.*p\.*n\.(?=[a-z0-9])'), 'registered practical nurse '),
    # HR
    (re.compile(r'\bh\.*r\.(?=[a-z0-9])'), 'human resources '),
    (re.compile(r'\bh\.*r\.*(?!\S)'), 'human resources'),
    # Customer service reps
    (re.compile(r'\bc\.*s\.*r\.(?=[a-z0-9])'), 'customer service representative '),
    (re.compile(r'\bc\.*s\.*r\.*(?!\S)'), 'customer service representative'),
    (re.compile(r'\bcustomer service rep\.*(?!\S)'), 'customer service representative'),
    # qa / qc
    (re.compile(r'\bq\.*a\.(?=[a-z0-9])'), 'quality assurance '),
    (re.compile(r'\bq\.*a\.*(?!\S)'), 'quality assurance'),
    (re.compile(r'\bq\.*c\.(?=[a-z0-9])'), 'quality control '),
    (re.compile(r'\bq\.*c\.*(?!\S)'), 'quality control'),
    # database administrator
    (re.compile(r'\bdba\b'), 'database administrator'),
    (re.compile(r'\bdatabase admin\b'), 'database administrator'),
    (re.compile(r'\bdb admin\b'), 'database administrator'),
    # Instrumentation and electrical
    (re.compile(r'\bi/e\b'), 'instrumentation and electrical'),
    # financial service representative
    (re.compile(r'\bfsr\b'), 'financial service representative'),
    (re.compile(r'\bfreelance\b'), 'freelancer'),
    (re.compile(r'\bdesiginer\b'), 'designer'),
    (re.compile(r'\bbiomed\b'), 'biomedical'),
    (re.compile(r'\bgoverenment\b'), 'government'),
    (re.compile(r'\bmachanic\b'), 'mechanic'),
    (re.compile(r'\bbusiness owner\b'), 'owner'),
    (re.compile(r'\br(\s)*&(\s)*d\b'), 'research and development'),
    (re.compile(r'\br and d\b'), 'research and development'),
    (re.compile(r'research/development'), 'research and development'),
    (re.compile(r'(\s)*&(\s)*'), '/'),
    (re.compile(r'(\s)*,(\s)*'), '/'),
    (re.compile(r'(\s)*/(\s)*'), '/'),
    (re.compile(r'(\s)*\|(\s)*'), '/'),
    (re.compile(r'(\s)+and(\s)+'), '/'),
    (re.compile(r'\beditor-in-chief\b'), 'editor_in_chief'),    
    # Remove all parens and there content
    (re.compile(r'\([\w\s\W\S]*\)'), ''),    
    #ESL
    (re.compile(r'^esl$'), 'english as a second language instructor'),
    (re.compile(r'^e\.*s\.*l\.* instructor$'), 'english as a second language instructor'),
    (re.compile(r'^e\.*s\.*l\.* teacher$'), 'english as a second language instructor'),
    (re.compile(r'^english as a second language$'), 'english as a second language instructor'),
    (re.compile(r'^english as a second language teacher$'), 'english as a second language instructor'),
    (re.compile(r'^e.s.l. instructor$'), 'english as a second language instructor'),
    (re.compile(r'^e.s.l. teacher$'), 'english as a second language instructor')
    ]

# %%
trans = {r: rep for r, rep in transforms}

# %%
raw_df['transformed'] = raw_df['function']

# %%
raw_df['transformed'].replace(trans, regex=True, inplace=True)

# %%
raw_df['transformed'].replace({"  ": " "}, regex=True, inplace=True)

# %%
raw_df['transformed'] = raw_df['transformed'].str.strip()

# %% [markdown]
# Remove all user profiles using non ascii characters

# %%
func_counts = raw_df['transformed'].value_counts()

# %%
eng = [isEnglish(s) for s in func_counts.index.values]
idx = [i for i, x in enumerate(eng) if x == False]
problematic = [func_counts.index.values[i] for i in idx]

# %%
bad_ids = raw_df[raw_df.transformed.isin(problematic)]["_id"].unique()

# %%
raw_df = raw_df[~raw_df["_id"].isin(bad_idsds)]

# %%
raw_df.to_pickle("/data/rali7/Tmp/solimanz/data/pickles/clean_aug.pkl")

# %%
matches = [s for s in func_counts.index if 'dba' in s]

# %%
matches
# Out:
# ['foodbank coordinator',
#  'broadband engineer',
#  'handbag buyer',
#  'neurofeedback technician',
#  'neurofeedback trainer',
#  'broadband technician',
#  'biofeedback specialist',
#  'broadband analyst',
#  'handbag designer',
#  'certified biofeedback specialist',
#  'handbalancer',
#  'neurofeedback practitioner',
#  'senior business analyst - broadband networks',
#  'dbase developer',
#  'foodbank volunteer coordinator',
#  'biofeedback therapist',
#  'director/broadband services',
#  'broadband systems technician',
#  'broadband support technician',
#  'broadband producer',
#  'online content/programming analyst - broadband entertainment',
#  'international accessories/handbags buyer',
#  'noc technician data/broadband',
#  'senior broadband product manager',
#  'broadband access strategy analyst',
#  'vice president broadband wireless access products',
#  'freelancer handbag designer',
#  'wireless broadband expert',
#  'broadband/wireless consultant',
#  'assistant buyer- handbags/accessories',
#  'manager - technical support broadband/ip technology centre',
#  'biofeedback technician',
#  'feedback analyst',
#  'senior manager/broadband wireless systems',
#  'associate director music/broadband/innovation',
#  'technical producer/broadband',
#  'foodbank caseworker',
#  'product manager broadband/interactive television',
#  'network specialist - broadband',
#  'manager - broadband access strategy',
#  'team lead/pricing - broadband/business local access',
#  'handbags/accessories buyer',
#  'senior manager/broadband wireless rf systems',
#  'corporate strategist - broadband for rural nova scotia initiative',
#  'product manager - wireline/broadband home/wireless accessories',
#  'broadband technical specialist',
#  'iptv/broadband product management',
#  'broadband canada program',
#  'group senior manager/broadband',
#  'assistant vice president/broadband policy',
#  'senior broadband producer',
#  'engineer-broadband access network',
#  'designer handbags sales associate',
#  'dbar server',
#  'biofeedback practitioner',
#  'analyst - broadband access strategy',
#  'hardband operator',
#  'owner/neurofeedback technician',
#  'broadband support',
#  'product manager - wireless broadband access',
#  'director broadband strategy',
#  'technical support engineer - broadband division of sify ltd.',
#  'broadband products engineer',
#  'applications engineer/broadband wireless',
#  'headbartender',
#  'broadband tier ii technician',
#  'broadband wireless solutions manager',
#  'senior market manager/consumer broadband',
#  'cochair/tri-services special purpose committee 700 mhz broadband for mission critical public safety',
#  'project manager/wireless/broadband',
#  'biofeedback therapist/counselor',
#  'head of broadband marketing/sales',
#  'assistant buyer/handbags',
#  'whatsup feedback canada/usa',
#  'handbag sales specialist',
#  'assistant handbag product developer',
#  'product marketing manager - broadband video entertainment',
#  'sales associate/handbags',
#  'handbag specialist',
#  'bio-feedback technician/health coach',
#  'handbags department manager',
#  'patient feedback intake coordinator',
#  'broadband service technician',
#  'broadband product manager',
#  'neurofeedback therapist',
#  'broadband support specialist',
#  'professional handball player',
#  'bandbary operator',
#  'product manager - broadband',
#  'feedback coordinator',
#  'handbag/accessories designer',
#  'hd technician red seal journeyman @ hudbay minerals',
#  'broadband/wimax rf network design',
#  'feedback officer',
#  'broadband/ip network engineering',
#  'brand manager handbags/small leather goods',
#  'network manager - broadband/ip provisioning/commissioning',
#  'beneficiary feedback field research consultant',
#  'resolution management/customer feedback officer',
#  'clinical neurofeedback technician',
#  'student feedback survey administrator',
#  'professinal european handball player',
#  'pc/lan analyst/mcse/mcdba/a+',
#  'broadband network analyst ii',
#  'feedback/recruitment intern',
#  'research assistant in broadband communications lab',
#  'sheri sopczak owner chicks/girlies leather handbag design company',
#  'director - network strategy/broadband/security',
#  'biofeedback therapist - www.academyofwellness.com',
#  'owner/biofeedback practitioner',
#  'business analyst - broadband network capital governance',
#  'senior manager data/broadband operations',
#  'associate merchandise marketing manager - ladies accessories/handbags/footwear',
#  'manager - broadband applications',
#  'project officer/national broadband task force',
#  'broadband network technical advisor',
#  'planning/design engineer-hfc broadband network',
#  'public relations/biofeedback counsellor',
#  'lead engineer - broadband access',
#  'aerialist/handbalancer',
#  'communications specialist - broadband networks',
#  'product verification/broadband wireless access',
#  'financial controller/fp/a manager - broadband/networks',
#  'professional facilitator -employer-led resume feedback',
#  'assitant manager multimedia/broadband core',
#  'buyer/branded/contemporary handbags',
#  'project manager of broadband solutions',
#  'manager broadband services/project lead sd',
#  'retail sales associate- chanel handbags boutique',
#  'president/ldba',
#  'mobile broadband network core engineering consultant',
#  'project leader/residential broadband/customer operations',
#  'buyer - handbags/wallets/belts',
#  'european handball referee',
#  'director broadband services',
#  'neurofeedback consultant',
#  'merchandise manager- diamondback',
#  "concert series manager - qatar 2015 men's handball world championship",
#  'broadband/mobile helpdesk specialist',
#  'designer of ladies handbags/apparel',
#  'junior sous chef cafe/dbar',
#  'software team leader/architect - broadband wireless access',
#  'divisional merchandise manager - jewellery/accessories/handbags/luggage',
#  'ceo/neurofeedback/hyperbaric medicine specialist/performance coach',
#  'mathematics gradball director',
#  'biofeedback software product manager',
#  'registered massage therapist/biofeedback therapist',
#  'principal rf design engineer - mobile broadband networks planning/engineering',
#  'optical broadband product snmp software developer',
#  'pom handbags/acc - little burgundy',
#  'director - network strategy/broadband 2000',
#  'operations manager - pcn/broadband/wireless',
#  'senior advisor- broadband service management/professional in business process management',
#  'software engineer - broadband wireless access',
#  'director of broadband infrastrucure program',
#  'manager/broadband operations',
#  'project manager/synthetic aperture radar [sar]/broadband comms',
#  'secretary/call coordinator/foodbank administrator volunteer',
#  'sales associate/designer handbags',
#  'shaft sinking hudbay',
#  'manager customer service - broadband service assurance/provisioning',
#  'director development handbags/sunglasses',
#  'neurofeedback consultant/trainer',
#  'merchandise manager handbags/small leather goods',
#  'broadband manager',
#  'consumer market manager - broadband',
#  'associate director/broadband/ip planning',
#  'senior software designer - broadband',
#  'foodbank intake worker',
#  'psychometrist/bio-neurofeedback/psychotherapy',
#  'head of pmo p25/broadband 700',
#  'medical biofeedback specialist/stress/pain/performance specialist',
#  'administrator of powerful professionals consulting skills 360 client feedback survey',
#  'project manager - access broadband',
#  'manager/policy/liaison/broadband canada',
#  'senior programmer - dbase iii/clipper',
#  'residential broadband content manager',
#  "assistant buyer/merchandising- luxury/vintage handbags/accessories/men's apparel/beauty/footwear",
#  'associate director - consumer broadband development',
#  'general manager/information technology infrastructure/broadband/data centers',
#  'handbags/accessories assistant buyer',
#  'area sale manager - designer handbags/small leather goods/ladies wear',
#  'senior program manager - broadband process improvement teams:',
#  'operations supervisor -- broadband national/bridgevine',
#  'chief technology officer - columbia basin broadband corporation',
#  'senior manager/inventory management - womens footwear/handbags/accessories',
#  'merchandiser - handbags/wallets - access division',
#  'system manager - broadband access networks',
#  'dbar of daniel boulud',
#  'communication engineer - broadband',
#  'member national selection committee broadband industry canada',
#  'business development - broadband video',
#  'primetime pa for hardball with chris matthews/deborah norville tonight',
#  'sales manager of ladieswear/lingerie/kidswear/accessories/coach handbags',
#  'software developer in the broadband wireless access group',
#  'buyer - handbags/small leather goods',
#  'feedback/inventory',
#  'director/broadband access solutions',
#  'broadband coordinator/technical support analyst',
#  'general manager - broadband systems',
#  'art therapist/neurofeedback clinician',
#  'process management/feedback engineer - thermal team leader',
#  'sessional lab instructor - se 380 "intro to feedback control"',
#  'president/broadband networks group/comlink/ebs',
#  'marketing analyst/broadband networks marketing',
#  'clinical supervisor/feedback informed treatment project lead',
#  'trunking/switching technician - broadband facility control office',
#  'broadband vpn specialist',
#  'feedback from colleagues',
#  'product specialist-broadband networks',
#  'distributor/handbags/luggage',
#  'senior manager/partner solutions/broadband access',
#  'web producer/e-commerce - online categories: fashions/handbags/shoes/home goods/clearance',
#  'neurofeedback trainer/counsellor at trent view counselling',
#  'mobile broadband solutions manager',
#  'judge/feedback panel',
#  'broadband performance analyst',
#  'manager - technology strategy/mobile broadband network deployment',
#  'research assistant/broadband feasibility study',
#  'broadband services technician',
#  'neurobiofeedback technician',
#  'sandbanks provincial park maintenance',
#  'news reporter/anchor at 880 cklq/94.7 star fm/feedback producer',
#  'broadband telecommunications engineer',
#  'business strategy manager/broadband entertainment',
#  'contract senior copywriter/broadband networks',
#  'sales specialist associate/head of department for coach handbags',
#  'merchandise assistant planner/ladies handbags',
#  'landbase operator',
#  'senior technician of broadband internet service',
#  'broadband operations manager',
#  'dsa at gucci handbags/accessories',
#  'broadband intern',
#  'professional european handball player',
#  'customer service in implementation of broadband internet connections',
#  'staff systems engineer/project coordinator/broadband wireless division',
#  'manager/handbags/accessories',
#  'program manager - broadband wireless infrastructure',
#  'test/integration engineer - mobile/broadband applications',
#  'director/development/operations/broadband video',
#  'senior broadband engineering/information manager',
#  'turf crew - diamondback golf club',
#  'clinical assistant/neurofeedback technician',
#  'accessories/handbags merchandise manager-aldo international',
#  'landbase stewardship/ecosystems section head',
#  'feedback administrator',
#  'buyer - nw handbags/enzo footwear',
#  'manager/maxis broadband',
#  'product designer/graphic designer of handbags/shoes/accessories',
#  'handbag wizzard',
#  'broadband tier2 of bell aliant',
#  'design consultant - handbags',
#  'seasonal sales associate - ladies accessories/handbags',
#  '360 feedback administrator',
#  'international accessories/handbag buyer',
#  'buyer accessories/handbags',
#  'associate buyer - handbags/seasonal accessories',
#  'sales specialist: ladies accessories/handbags',
#  'eeg biofeedback therapy administrator',
#  'planning analyst - footwear/handbags',
#  'category coordinator - jewellery/watches/handbags/accessories',
#  'vice president events/gdba/gcba society',
#  'broadband helpdesk',
#  'broadband network operations',
#  'director/customer/small business/community investment/broadband network communications',
#  'engineering/design specialist-broadband osp',
#  'senior manager - mobile broadband oss',
#  'sales associate - accessories/handbags',
#  'manager; customer/employee feedback - personal deposits/investments',
#  'broadband sales engineer',
#  'leadership development/dealing with difficult situations/giving/receiving feedback',
#  'senior mgr/access broadband planning',
#  'technical advisor - broadband business planning',
#  'consumer products/services - broadband cpe',
#  'assistant handbag buyer',
#  'manager/ss7 broadband stp development',
#  'worldbankprojectinhousingproject',
#  'solution manager ip/broadband',
#  'technical manager/corporate feedback/opex/and technology watch',
#  'director of sales/broadband markets',
#  'senior software designer residential broadband cornerstone resource manager',
#  'buyer/handbag',
#  'engineer - broadband design/project manager',
#  'broadband coordinator',
#  'manager broadband/ip analyst',
#  'broadband marketing coordinator',
#  'patient feedback/patient representative system developer',
#  'broadband mobile wireless prototype/system designer',
#  'marketing manager/operational marketing/broadband networking division',
#  'landbase stewardship section head',
#  'luxury handbag consultant',
#  'owner/aesthetician/biofeedback practioner/laser technician/nail tech/educator',
#  'sales representative - handbags/designer handbags',
#  'gsm - ladies fashions/jewellery/watches/footwear/handbags/accessories',
#  'manager broadband planning/engineering - access standards',
#  'focus/feedback dev support coordinator',
#  'certified quantum biofeedback specialist/life coach',
#  'certified biofeedback specialist/instructor/diplomate',
#  'general manager buying- handbags/accessories',
#  'theoldbarndoor',
#  'theweddinghandbag.com',
#  'department manager designer/bridge handbags',
#  'headband designer/founder',
#  'handbag production manager',
#  'senior planning manager - footwear/handbags',
#  'product line manager - broadband services - emea',
#  'senior manager/next generation nationwide broadband network project',
#  'ellen tracy handbags director',
#  'dbarc facility attendant',
#  'senior handbag designer',
#  'manager/broadband solutions',
#  'broadband services tpm',
#  'project coordinator broadband wholesale/bell business markets',
#  'project manager/documentation/dbase',
#  'buyer - accessories/jewellery/handbags',
#  'manager broadband',
#  'analyst - facilities management/product feedback',
#  'gucci handbags specialist',
#  'administrative assistant/distribution/consumer isp/broadband/marketing',
#  'manager/broadband business unit',
#  'brand manager assistant/shoes/handbags division',
#  'merchandise associate - handbags',
#  'project coordinator - branding for qatar 2015 world handball championship',
#  'landbank of the philippines',
#  'marketing manager- entertainment/broadband/voice',
#  'avp program management (broadband wireless',
#  'senior mobile broadband systems consultant',
#  'senior digital manager/broadband production',
#  'embedded sw designer - ome broadband',
#  'broadband research engineer',
#  'bus 100 feedback analyst',
#  'associate director marketing - business markets broadband',
#  'broadband acquisition manager',
#  "featured talent manager/ceremonies - qatar 2015 men's handball world championship",
#  'merchandise planner/designer handbags',
#  'head handbag designer',
#  'internet explorer program manager - customer feedback',
#  'neurofeedback training consultant',
#  'pom - accessories/handbags/footwear for call information technology spring',
#  'sales manager--broadband communications--ontario government',
#  'acupuncture/biofeedback sessions',
#  'manager/digital tv/broadband software development',
#  'broadband internetworking engineer',
#  'divisional vice president/dpm jewelry/handbags/watches',
#  'buyer for accessories/handbags',
#  'buyer-handbags/accessories',
#  'shop manager-coach handbags',
#  'dsl specialist - bharti broadband services - airtel',
#  'embeded sw developer - ome broadband',
#  'senior buyer: handbags/accessories',
#  'vice president broadband/marketing',
#  'broadband maintenance technician',
#  'consultant to the wireless broadband industry',
#  'senior pc/lan analyst/mcse/mcdba/a+',
#  'group planning manager - jewelry/handbags/accessories',
#  'bbnoc broadband noc manager',
#  'sales manager - ladieswear/lingerie/shoes/luggage/handbags/ladies acc./',
#  'account manager - wireless broadband',
#  'merchandise coordinator/ladies apparel/handbags',
#  'buyer - accessories/handbags',
#  'owner/deposit broker-member rdba',
#  'executive coach/adjunct coach/360 feedback/small group facilitator',
#  'computer development specialist - broadband networks engineering',
#  'manager/consumer broadband services/telus tv team',
#  'site manager - opening/closing ceremonies of the 2015 world handball championships',
#  'broadband draftsperson/cad operator',
#  'senior architect - residential broadband',
#  'procurement manager - broadband technology',
#  'merchandise specialist/jewelry/handbags/accessories',
#  'neurofeedback/biofeedback certified trainer',
#  'head handbags designer',
#  'manager customer service - broadband/ip process team lead',
#  'director/iptv/mobile/broadband',
#  'broadband application engineer/network system engineer/technology advisor',
#  'owner/quantum bioffedback specialist',
#  "group sales manager- cosmetics/accessories/handbags/jewelry/footwear/men's denim",
#  'broadband/in engineer',
#  'pm broadband for schools',
#  'head of acquisitions/broadband entertainment',
#  'junior web usability/feedback officer',
#  'designer- ladies handbags/accessories',
#  'fendi handbag specialist/paul smith specialist/theory specialist/watch specialist',
#  'validation engineer/broadband wireless access/dallas/texas',
#  'proposal coordinator/holdback release administrator',
#  'information technology manager - wireless broadband group',
#  'asst. product manager/development - handbags',
#  'director/broadband internet solutions/at/t canada',
#  'acquisition/strategy manager mobile broadband',
#  'special advisor/broadband canada program',
#  'handbags/accessories buyer - aldo france/information technology aly/austria',
#  'manager - process improvement broadband/ip',
#  'broadband customer care centre - team lead',
#  'senior graphic designer for northern lincs broadband team',
#  'vice president business dev at candam/certified silver fotoware partner/laidback solutions partner',
#  'worldcall broadband limited',
#  'birdbath',
#  'account manager - broadband - western canada',
#  'broadband researcher',
#  'project manager/broadband educational technology',
#  'broadband oam/p planning manager/international standards',
#  'prada handbag specialist',
#  'senior manager broadband/transport atlantic canada',
#  'biofeedback/neurofeedback practitioner',
#  'broadband services architect',
#  'registered biofeedback therapist',
#  'coach handbags sales associate',
#  'coach broadband/ip business office',
#  'audience feedback project coordinator',
#  'sales manager at glentel inc/multi-carrier cell phone/mobile broadband consultant',
#  'country manager /broadband networking division',
#  'technical sales manager/mobile broadband',
#  'assistant buyer/product developer handbags/accessories',
#  'sales/designer handbags',
#  'neurofeedback instructor',
#  'broadband technology strategist',
#  'buyer - fashion accessories/handbags',
#  'manager customer service - broadband process prime',
#  'product manager - broadband video/audio',
#  'certified biofeedback practitioner',
#  'buyer- footwear/handbags/accessories/lifestyle',
#  'technical program manager - mobile broadband solutions',
#  'handbags/small leather goods designer',
#  'national manager/client feedback',
#  'handbags + accessories sales associate',
#  'design director/handbags',
#  'western student recreation centre soccer/badminton/european handball convener',
#  'p.a/department manager/rtms/neurofeedback technician',
#  'sales manager/accessories/handbags',
#  'handbag product developper director',
#  'communications manager - broadband networks',
#  'cafe boulud/dbar host',
#  'internet broadband installation technician',
#  'team lead accessories/handbags',
#  'technical architect - broadband',
#  'tier ii broadband - technical support',
#  'general manager multimedia/broadband/coordination.',
#  'handball press',
#  'analyst - broadband canada program',
#  'client support broadband specialist',
#  'account manager/broadband network solutions',
#  'broadband application adoption coach',
#  'cafe boulud/dbar assistant manager',
#  'senior business analyst/program management office - broadband networks',
#  'associate director - ba broadband customer service design/costing',
#  'goldmine dbase administor',
#  'groups vice president/general manager/broadband access division',
#  'certified biofeedback specialist/certified personal lifestyle coach/nutrition specialist',
#  'connected capital area broadband consortium - fellow',
#  'senior project manager/project information technology tehad/broadband development.',
#  'vice president/handbags/travel bags/accessories',
#  'merchandise manager/handbags buyer',
#  'jewelry handbags watches sunglasses',
#  'vice president of sales/wireless broadband for the americas',
#  'broadband support training',
#  'emotional healing coach/ therapist/bio feedback therapist/',
#  'sales manager - jewellery/handbags/coach/accessories',
#  'network manager - broadband/ip network engineering',
#  'project manager- broadband team',
#  'senior architect - broadband',
#  'analyst/broadband access strategy',
#  'volunteer at the central student association foodbank',
#  'director/broadband/digital',
#  'classification specialist for handbag/small leather good department',
#  'chief executive officer of bbrcnx/neurofeedback training',
#  'sales associate handbags',
#  'translator + subtitling feedback specialist',
#  'senior broadbant analyst',
#  'i/information technology policy advisor/broadband initiative/office of the corporate chief strategist',
#  'regional manager - broadband/ip network',
#  'team lead/broadband',
#  'broadband wireless group intern',
#  'senior network architect - broadband access network',
#  'regional manager operations ip/broadband support',
#  'family therapist/biofeedback technician',
#  'beta tester/feedback',
#  'broadband internet strategic project chief',
#  'enterprise feedback management implementation consultant',
#  'stylist - designer handbags',
#  'office administrator/neurofeedback technician',
#  'allocator/replenisher/handbags',
#  'designer/product developer -handbags/accessories',
#  'fast feedback resolver: jeep electrical/electronic systems - daimlerchrysler',
#  'buying coordinator i handbags/wallets/and belts',
#  'cpe design specialist i - broadband access standards',
#  'foodbank guest services intern',
#  'broadband cable service technician',
#  'ladies footwear/handbag buyer - shoe warehouse division',
#  'sales associate- handbags/coach',
#  'director marketing - voice/broadband',
#  'project leader - 360 degree leadership feedback program',
#  'hughes boradband satellite network engineer - system engineer',
#  'sales team leader -- coach handbag',
#  'practitioner of quantum biofeedback',
#  'biofeedback/stress/pain support',
#  'broadband/ip network engineer',
#  'associate director/broadband wireless',
#  'bss/ran network field maintenance - gsm/umts/wireless broadband/transmission/radio etisalat',
#  'roudbar lorestan dam internship',
#  'feedback informed treatment',
#  'broadband tv youtube channel recruiter 2014',
#  'designer/dbase developer',
#  'sales representative -- coach handbag',
#  'quantum biofeedback therapy practitioner',
#  'vice president broadband/switching',
#  'undergraduate research assistant/peer feedback project',
#  'student feedback advisor',
#  'adsl broadband technician',
#  'virgin media broadband technical support',
#  'operations manager/network deployment/broadband networks',
#  'designer/luxury handbags department manager',
#  'senior wireless engineer - broadband wireless',
#  'owner- biofeedback specialist',
#  'accessories/handbags buyer',
#  'level 2 senior broadband technician',
#  'system design engineer - broadband wireless access',
#  'supervisor broadband/iptv',
#  'support specialist - voip/broadband troubleshooting/implementation',
#  'instructor/mba/gdba programs',
#  'broadband specialist',
#  'manager/residential broadband/customer operations',
#  'sales associate/ssa for kate spade handbags',
#  'visual merchandiser/handbags accessories',
#  'broadband access development leader',
#  'owner-biofeedback practitioner',
#  'channel development manager - broadband',
#  'team lead/feedback/reporting',
#  'support associate/handbags/designer womenswear',
#  'svp/gm - broadband switching/routing',
#  'student feedback survey promoter',
#  'patient feedback intake coordinator - patient relations',
#  'broadband wireless access - product verification/plm - senior manager',
#  'marketing specialist/consumer broadband',
#  'stress consulting/biofeedback',
#  'broadband connectivity solution engineer',
#  'consumer feedback analyst',
#  'designer handbags - sales',
#  'professional handball player - team captain',
#  'director/broadband sales western region',
#  'self employed handbag designer',
#  'clinic intern/biofeedback/nutrition trainee',
#  'certified holistic health practitioner/biofeedback therapist',
#  'broadband equipment specialist',
#  'wireline broadband access project management director',
#  'at/t broadband tier ii phone support',
#  'senior project manager - broadband evolution pmo',
#  'intern - assistant buyer: handbags',
#  'business analyst-broadband networks',
#  'neurofeedback/biofeedback trainer',
#  'various - vice president portal content/strategy/senior director/broadband/innovation/business development',
#  'technical support manager/boardband product',
#  'leather handbag designer',
#  'michael kors handbag specialist',
#  'business coordinator/handbags/accessories/jewellery/watches',
#  'network technician data broadband',
#  'designer handbag specialist',
#  'quantum biofeedback technician',
#  'broadband application engineer',
#  'mphil./in broadband network',
#  'broadband account manager',
#  'manager - broadband/ip network engineering',
#  'vp/mobile broadband networks implementation/operations/client support',
#  "women's footwear-handbag buyer/product developer",
#  'oss broadband access configuration manager',
#  'director broadband operations',
#  'broadband access specialist',
#  'broadband network design/construction',
#  'senior optical/broadband engineer',
#  'senior director/residential pricing/packaging - video/broadband/home phone/home security',
#  'consultant/rural broadband deployment',
#  'merchandise associate - handbags/wallets/and sunglasses',
#  'division manager/wireless broadband unit',
#  'senior technical analyst - broadband/ipvpn/mpls - provisioning/repair',
#  'head - broadband customer service/operations',
#  'handbag buying director',
#  'mohawk college/dbarc',
#  'massage therapist/success life coach/certified therapist/biofeedback therapist',
#  'kate spade handbag specialist',
#  'assistant brand manager - handbags',
#  'broadband/ip - process manager',
#  'manager/content partnerships/strategy - broadband video',
#  'manager of broadband wireless access engineering team',
#  'administrative assistant to vice president of broadband enginnering/bluetooth/ed roth/steve tsubota',
#  'product manager - broadband access development/product management',
#  'international junior buyer/accessories/handbags',
#  'chief broadband engineer',
#  'associate technical director/broadband/connectivity.',
#  'team leader - broadband implementation coordinators',
#  'senior researcher - public safety broadband',
#  'gadbar attendant/manager',
#  'senior engineer/public safety broadband',
#  'broadband field technician',
#  "buyer/ladies' handbags",
#  'managing director/vice president asia pacific broadband sector',
#  'information technology broadband security specialist',
#  'kinesiologist/biofeedback expert',
#  'broadband technician support',
#  'service provisioning executive - broadband',
#  'quality assurance anddba',
#  'senior network architect - optical/broadband',
#  "merchandise planning manager - luggage/handbags/men's accessories/seasonal/hosiery",
#  'department manager of jewellery/accessories/shoes/luggage/handbags',
#  'feedback/reporting analyst',
#  'manager - broadband/ip engineering',
#  'senior brand manager/elle handbags 2004-2005',
#  'visual merchandiser/handbags/jewelry/shoes',
#  'sendback coordinator',
#  'test manager/nedbank',
#  'staffing/recruiting consultant/teacher/biofeedback therapist',
#  'administrative assistant/ladies handbags wholesaler',
#  'sales manager - ladieswear/footwear/handbags/accessories/lingerie/credit champion',
#  'project manager - london broadband project',
#  'senior technical writer/interactive broadband',
#  'market analyst/broadband access',
#  'buyer - footwear/handbags/backpacks/luggage/wallets',
#  'manager technology strategy/operations - broadband networks planning/engineering',
#  'product manager - broadband services enablement',
#  'associate director - broadband planning/deployments',
#  'technical marketing manager: hsi/broadband access',
#  'senior buyer handbags/accessories',
#  'natural/adbas programer',
#  'vice president/general manager/aol dial/broadband',
#  'cable tv/telephony/broadband internet installation technician',
#  'cis purchase order management - handbags/accessories',
#  'quantum biofeedback specialist',
#  'sales/broadband consultant',
#  'director/development/operations - broadband entertainment',
#  "buyer/women's handbags",
#  'assistant buyer - ladies handbags',
#  'assistant program manager - product development broadband',
#  'broadband assistant divisional controller',
#  'broadband cable network facing technician',
#  'broadband services technology director',
#  'embeded sw designer - ome broadband',
#  'broadband advisor',
#  'senior manager/employee feedback/communication services',
#  'senior associate director/isp broadband strategy/planning',
#  'digital tv - broadband services analyst',
#  'assistant buyer/handbags/accessories',
#  'buyer- furniture/handbags/luggage/gifts/and accessories',
#  'buyer - handbags/wallets',
#  'associate handbag designer',
#  'broadband/bell west wholesale data',
#  'handbalancing coach',
#  'sandbagging supervisor',
#  'manager rf hw design/broadband wireless access',
#  'telecommunications broadband technician',
#  'buyer- handbags',
#  "women's accessories/handbags",
#  'neurofeedback/counselling',
#  'broadband video coordinator',
#  'senior broadband engineer',
#  'assistant manager multimedia/broadband',
#  'buyer - handbags/accessories',
#  'manager/broadband access product line',
#  'cofounder redbarn group',
#  'postdoctoral engineering research fellow/team leader of "broadband wireless communication group"',
#  'senior manager/broadband networks unified planning',
#  'eeg biofeedback trainer',
#  'dir broadband wireless',
#  'engineering manager/broadband wireless group',
#  'venue technical manager cricket/handball',
#  'senior footwear/handbag buyer',
#  'manager - operations wireline broadband network',
#  'buying intern - handbags/accessories',
#  'interactive cd-rom/broadband producer',
#  'executive assistant/corporate guest feedback leader',
#  'sales engineer/technology specialist/catv/broadband',
#  'hardball umpire',
#  'broadband project manager',
#  'general manager/cafe boulud restaurant/dbar',
#  'manager/mobile broadband',
#  'broadband business development',
#  'director of broadband architecture',
#  'quantum biofeedback practitioner',
#  'director/information technology systems architecture/delivery - broadband network inventory',
#  'nb broadband circuit coordinator',
#  'visiting lecturer - gdba/executive mba in aboriginal business/leadership',
#  'associate director product management - ip broadband/voice services',
#  'broadband content editor - rogers yahoo!',
#  'dbase group',
#  'client representative - residential/broadband technician/technical support associate',
#  'tidball construction',
#  'product designer/graphic designer of handbags/shoes/accessories/houseware',
#  'bilingual product feedback specilaist',
#  'design assistant - handbags',
#  'manager/development lab operations/broadband networks',
#  'broadband internet analyst',
#  'broadband policy/programs coordinator',
#  'broadband engineering manager',
#  'etv feedback/production coordinator',
#  'qwest broadband loyalty',
#  'handbags specialist',
#  'program manager for at/t digital broadband data/voice',
#  'searching for true love http://www.cdbaby.com/cd/romankahlone',
#  'senior buyer - handbags/wallets/belts',
#  'biofeedback specialist/natural health consultant',
#  'student feedback facilitator',
#  'head of dsl broadband division',
#  'associate director/network/broadband services',
#  'general manager/broadband networks division',
#  'senior product marketing manager - broadband',
#  '360 degree feedback coach',
#  'product manager - broadband access development',
#  'dbase management',
#  'project director/broadband for rural nova scotia',
#  'project consultant-hfc broadband network',
#  'handbag stylist',
#  'junior broadband engineer',
#  "freelancer stock associate - men's/women's rtw/handbags/accessories",
#  'assistant director/behaviour conultant/nvcpi instructor/neurofeedback trainer',
#  'senior marketing manager/business broadband',
#  'manager - broadband networks laboratory',
#  'mba/gdba program assistant',
#  'manager/broadband home development',
#  "ass't buyer handbags call information technology spring",
#  'manager broadband wireless standards',
#  'handbag technologist',
#  'broadband advisory committee member',
#  'viewer feedback',
#  'senior site manager - handball world championships opening/closing ceremony',
#  'certified bio-feedback adviser',
#  'director of sales/marketing - wireless/broadband networks',
#  'manager/mobile broadband pricing',
#  'foodbank intake/assessment worker',
#  'consultant/broadband interactive tv division',
#  'broadband solutions/services planning',
#  'headwaiter-/headbartender',
#  'product analyst - wireless broadband access/marketing',
#  'network infrastructure manager - columbia basin broadband corp.',
#  'sales account director - canadian/broadband sales',
#  'broadband technical support/service improvement leader',
#  'manager/broadband/ip engineering',
#  'senior engineer/gpon broadband implementation network development/build quality.',
#  'senior manager - broadband product marketing',
#  "assistant buyer/women's designer footwear/women's designer handbags",
#  'director/broadband policy',
#  'design director/leather goods-handbags/belts/small leather goods',
#  'avp global marketing/broadband access division',
#  'wireless broadband technician',
#  'manager/commercial broadband/customer operations',
#  'director merchandising handbags/wallets/accessories',
#  'ipvpn/broadband manager/business data provisioning',
#  'senior technologist - broadband over ka band',
#  'product/business analyst - broadband entertainment - consultant',
#  'broadband satellite engineer',
#  'director project management office - broadband implementation',
#  'product manager - pricing/product marketing/consumer mobile broadband',
#  'customer feedback analyst',
#  'distributor handbags call information technology spring',
#  'handbag/shoe design intern',
#  'director/program management office - broadband networks',
#  'planning manager/winners/stylesense - beauty/handbags/luggage',
#  'coowner/neurofeedback technician',
#  'senior manager/broadband information technology v development',
#  'merchant handbag intern',
#  'technical trainer - broadband networks',
#  'broadband/connected home - senior network architect',
#  'senior vice president/tdbank - canadian banking/auto finance/credit cards',
#  'senior planner - broadband/fibre-to-the-home',
#  'documentary producer/"headbanger in heels"',
#  'general manager multimedia/broadband/coordination',
#  'researcher at broadband communication research lab',
#  'president/hudbay peru',
#  'cable broadband',
#  'kasdba rceptionist',
#  'atm broadband wireless access software developer',
#  'divisional merchandise manager jal: jewelry/accessories/handbags/luggage',
#  "head designer/women's headwear/handbags division",
#  'broadband sales manager/canada',
#  'project leader/senior engineer/broadband wireless access',
#  'team lead - lifecycle management/service development for ip/broadband',
#  'dbartisan software developer',
#  'broadband wiring technician',
#  'software engineer/broadband technologies',
#  'implementation analyst - broadband services',
#  'director at sindbad day camp',
#  'dbar/cafe boulud hostess',
#  "associate planner in marshall's-ladies accesories/handbags/luggage",
#  'project manager broadband',
#  'director product management broadband solutions',
#  'feedback interviewer',
#  'dbase programmer',
#  'neurofeedback program director/nurse',
#  'allocation replenishment analyst i handbags/fashion accessories',
#  'product coordinator/aldo handbags',
#  'assistant distributor handbags',
#  '4th year design project - robotic hand with tactile feedback',
#  'project manager in broadband convergence',
#  'fashion director: watches + handbags',
#  'fast ball/hardball umpire',
#  'manager - broadband surveillance/support',
#  'associate director - ip/broadband network operations',
#  'international accessories/handbag product director',
#  'senior technical support engineer - fixed/broadband',
#  'task completion craft feedback coordinator',
#  'independent biofeedback practitioner',
#  'ftth mdu deployment manager - broadband networks - ab north',
#  'broadband/ip network management eng.',
#  'researcher - broadband/ip planning',
#  'broadband task force chair',
#  'svp broadband business unit',
#  'member of the faab flight attendant feedback team for fa contract',
#  'enterprise/broadband marketing project manager',
#  'biofeedback practitioner/colon hydrotherapist',
#  'buyer handbags/wallets',
#  'merchandise associate designer handbags - buying group',
#  'frontlinedba/counter management for clarins',
#  'broadband cable technician',
#  'buyer handbags/accessories',
#  'assistant designer handbag/accessories.',
#  'broadband operations planning',
#  'wireless broadband network specialist',
#  'assistant golf professional - diamondback',
#  'broadband tier ii',
#  'broadband sales representative',
#  'crafter: scarves/jewelry/headbands....',
#  'hostess: dbar',
#  'temporary chief technologist/ppl/assistant hematology/bloodbank supervisor',
#  'manager/broadband access strategy',
#  'feedback coach',
#  'product manager - broadband products/services',
#  'program coordinator - level 2 ip/broadband support',
#  'dir. of neurofeedback services',
#  'senior allocation analyst handbags/small leather goods',
#  'certified neurofeedback technician',
#  'network analyst ii - broadband operations',
#  'product manager - broadband audio/video',
#  'director - broadband deployment',
#  'manager/broadband marketing program',
#  'bio feedback/health counsel provider',
#  'patient intake/feedback coordinator',
#  'national account manager internet/broadband services',
#  'managing consultant: broadband operations planning/development',
#  'assistant buyer/designer handbags',
#  'accountemp/contract/with great feedback/referances',
#  'volunteer work - handbags for hospice fundraiser',
#  'beach handball world championships sport presentation manager/veneu producer',
#  'handball coach',
#  'hostess/dbar',
#  'client feedback coordinator',
#  'senior director/consultant - wireless/broadband networks',
#  'buyer footwear/handbags/fashion accessories',
#  'leader broadband access validation',
#  'broadband sequence local champion',
#  'independent consulting - amita/exray broadband/abbott/etc.',
#  'director of marketing - ip/broadband data services',
#  'gdba student at john molson school of business',
#  'head of mobile broadband/customer experience management expert pool - ses - middle east/africa',
#  'manager - broadband/ip provisioning team',
#  'outcome/feedback development manager',
#  'restaurant manager- the sandbar seafood restaurant',
#  'director of sales/wireless broadband',
#  'diamondback golf club',
#  'wireless/broadband business development',
#  'student feedback assistant',
#  'buyer/handbags/soft accessories/cold weather accessories',
#  'firmware design engineer level 1/broadband wireless division',
#  'handbags/accessories sales associate',
#  'senior consultant - head of broadband department',
#  'broadband wireless product verfication',
#  'coop wireless/broadband design manager',
#  'buyer assistant- handbags',
#  'manager cafe boulud/dbar',
#  'senior engineer broadband networks',
#  'director programming/marketing/broadband entertainment',
#  'marketing specialist - broadband networks',
#  'broadband to the home project manager',
#  'partner/laidback we "r" inc.',
#  'broadband product marketing',
#  'technical support specialist - broadband services',
#  'consultant in android mobile development for the muse brain sensing headband',
#  'national customer feedback coordinator',
#  'firmware design engineer level 2/broadband wireless division',
#  'technical lead engineer for telus broadband access/edmonton alberta',
#  'managing director/head north american fixed income/td securities/svp/tdbank group',
#  'broadband repair technician',
#  'graduate researcher/broadband communications research lab',
#  'avp broadband copper access business group',
#  'policy/liaison/broadband canada',
#  'community kitchens training/foodbank communications work',
#  'wireless broadband',
#  'broadband',
#  'handbag product developer',
#  'broadband noc',
#  'dbaoracle - implementation team lead',
#  'psychometrist/neurofeedback/rehabilitation',
#  'broadband access system architect',
#  'senior broadband network planner',
#  'marc by marc jacobs sales specialist: handbags',
#  'buying intern - handbags',
#  'biofeedback therapist/clinical psychologist/founder/owner',
#  'technical support specialist - broadband',
#  'landbase specialist',
#  'handbag designer/maker',
#  'manager - broadband engineering',
#  'head of broadband services',
#  'broadband oss support engineering',
#  'server/saladbar attendant',
#  'vice president general manager - broadband division',
#  'broadband tier ii analyst',
#  'formation en neurofeedback',
#  'associate director/b2b broadband investment review/product portfolio management',
#  'database administrator/ocp/mcdba/pmp',
#  "writer - 'negative feedback'",
#  'acting head of acquisition/strategy mobile broadband',
#  'marketing manager/biofeedback therpist',
#  'intramural indoor soccer/volleyball/team handball/outdoor soccer convenor',
#  'director of business development/broadband technologies',
#  'designer - handbag specialist',
#  'neurofeedback technician/public relations',
#  'broadband network maintenance technician',
#  'e-commerce merchandise associate/shoes/handbags',
#  'clinical counsellor/neurofeedback trainer',
#  'senior product manager/broadband access',
#  'senior - broadband tier ii',
#  'sales - media - home phone/broadband',
#  'channel/broadband marketing manager',
#  'director of ip telephony/broadband services',
#  'foldback sound',
#  'neurofeedback/shamanic services/reiki',
#  'broadband construction manager on contract',
#  'assistant manager landlines/broadband sales',
#  'broadband/microwave/catv technician',
#  'ladies handbags sales associate',
#  'president/broadband',
#  'biofeedback coach',
#  'sales manager/designer handbags',
#  'board member/cochair rural broadband working group',
#  'test engineering - broadband wireless access',
#  "visual merchandiser for women's contemporary/handbags/soft accessories",
#  'purchase order administrator - globo/call information technology spring handbag division',
#  'assistant distributor accessories/handbags uk',
#  'analyst ii/broadband networks',
#  'oracledba/database/software consultant/system analyst/programmer',
#  'director/product management/broadband access',
#  'engineering technician - broadband department',
#  'handbag/accessories buyer- canada',
#  'client solutions team manager mcp/mcsa/mcse/mcdba',
#  'accessories/handbags merchandise manager - aldo international',
#  'ticket seller at nedbank golf challenge',
#  'manager - broadband/ip network planner',
#  'aerialist/handbalancer/dancer',
#  'gmm dvp jewelry/handbags/accessories/luggage/footwear/cosmetics/fragrances',
#  'field of play - handball',
#  'senior manager - broadband deployment',
#  'director/regulatory - content distribution/broadband policy',
#  'product feedback analyst',
#  'system manager/canada public safety broadband lte',
#  'server/dbar',
#  'dsl broadband engineer',
#  'director quality/risk management-client feedback program',
#  'handbags/accesories designer',
#  'manager - broadband service development',
#  'senior associate director - consumer internet/voice services/broadband product development',
#  'project coordinator/project management in video conferencing/broadband',
#  'broadband product developer',
#  'program office manager -broadband networks/engineering',
#  'director/mba/gdba programs',
#  'lecturer/gdba program',
#  'editor/feedback magazine',
#  'quantum biofeedback practitioner/tesla metamorphosis practitioner/lifestyle coach',
#  'regional broadband technican',
#  'next gen broadband reporter',
#  'gdba blogger',
#  'allocator - handbags/mens bags/wallets',
#  'manager - product marketing/broadband/voice services',
#  'field support engineer/broadband networks',
#  'vice president wireless/broadband/content policy',
#  'sales manager of cosmetics/fragrances/footwear/coach handbags/accessories',
#  'broadband escalation manager',
#  'project manager - niagara regional broadband network',
#  'senior program manager/data/insights - broadband networks',
#  'international buyer - asia/southern hemisphere/aldo accessories/handbags',
#  'senior oracle database administrator/lead offshore dbas',
#  'business development - broadband internet services',
#  'information technology em master prime - broadband wireless access',
#  'tubular management/oil/gas- hardband division',
#  'massage/quantum biofeedback therapist',
#  'senior allocator - footwear/allocator - footwear/accessories/handbags',
#  'broadband product strategy manager',
#  'director/marketing/programming/broadband entertainment',
#  'junior editor/bertelsmann broadband group/cologne',
#  'merchandising intern for kenneth cole new york/reaction ladies shoes/handbags',
#  'broadband sales consultant',
#  'buyer - handbags/accessories/wellness',
#  'broadband oss developer coop',
#  'wimax/broadband wireless engineer',
#  'cable broadband installer',
#  'assistant buyer - handbags',
#  'internet/broadband technician',
#  'director/counsel/copyright/broadband law',
#  'senior business analyst - broadband network capital governance',
#  'broadband analyst ii',
#  'market research/client feedback',
#  'buying coordinator/handbags',
#  'broadband content specialist',
#  'director strategy business development -broadband networks',
#  'assistant product manager-aldo handbags',
#  'product manager/internet/broadband technologies',
#  'staff writer at bluebirdbanter.com',
#  ...]

# %%
with open("/data/rali7/Tmp/solimanz/data_viz/top_titles.txt", "w") as f:
    f.write(fmtcols(func_counts.index.values[:550], 4))

# %%
top_550 = func_counts[:550]
bad_ids = raw_df[~raw_df.transformed.isin(top_550.index)]["_id"].unique()
all_ids = raw_df["_id"].unique()
dataset_ids = list(set(all_ids) - set(bad_ids))
len(dataset_ids)
# Out:
# 101906
