# %% [markdown]
# # Analysis

# %%
import pandas as pd
import numpy as np
import json
import pickle
from collections import Counter, defaultdict
import matplotlib.pyplot as plt
import seaborn as sns
from ggplot import *
from sklearn.metrics import confusion_matrix
import nltk
from nltk.util import ngrams
from bidict import bidict
from collections import Counter, defaultdict
from nltk.corpus import stopwords
from statistics import mean
import sys
import os
import kenlm
from itertools import product
if "/u/solimanz/development/career_prediction_gpu/" not in sys.path:
    sys.path.append("/u/solimanz/development/career_prediction_gpu/")

# %%
# %matplotlib inline
plt.style.use(['dark_background', 'ggplot'])
sns.set(color_codes=True)
sns.set_palette(sns.color_palette('dark'))

# %%
sns.set_palette(sns.color_palette('dark'))

# %%
def topK_accs_df(preds, targets, seq_lengths):
    df_dict = {"model": [],
               "length": [],
               "acc": [],
               "top_2_acc": [],
               "top_3_acc": [],
               "top_4_acc": [],
               "top_5_acc": []}
    
    length_groups = groupby_length(seq_lengths)    
    for model, pred in preds.items():
        for k in range(1, 6):
            accs = accuracy_by_length(pred, targets, length_groups, k)
            for length, acc in accs.items():                
                if k == 1:
                    df_dict["acc"].append(round(acc, 5)*100)
                    df_dict["length"].append(length)
                    df_dict["model"].append(model)
                else:
                    df_dict[f"top_{k}_acc"].append(round(acc, 5)*100)
        
    return pd.DataFrame(df_dict)

def groupby_length(seq_lengths):
    d = dict()    
    for i in range(2, seq_lengths.max()+1):
        d[i] = np.where(seq_lengths == i)[0]
        
    return d

def next_batch(path):
    batch = 0
    name = os.path.basename(path)
    while os.path.exists(os.path.join(path, f"{name}_batch_{batch}.npy")):
        with open(os.path.join(path, f"{name}_batch_{batch}.npy"), "rb") as f:
            matrix = np.load(f)
        batch += 1
        yield matrix
        
def accuracy_by_length(preds, targets, groups, k=1):
    """
    preds: predictions of the model (n_examples, max_length, n_labels)
    targets: prediction targets with shape (n_examples, max_lenth, n_labels)
    groups: dictionary grouping the indices of the input sequences by length"""
    
    length_acc = dict()    
    for length, indices in groups.items():
        if len(indices) > 0:
            if len(preds.shape) == 3:
                p = preds[indices, length-1, :]
                t = np.argmax(targets[indices, length-1, :], axis=1)
                length_acc[length] = top_k_acc(p, t, k)
            else:
                p = preds[indices]
                t = targets[indices]
                length_acc[length] = top_k_acc(p, t, k)
        
    return length_acc

def to_python_lists(np_arr, lengths):
    return [row[:length] for row, length in zip(np_arr, lengths)]

def count_transitions(sequences):
    trans = [list(zip(seq[:-1], seq[1:])) for seq in sequences]
    trans = sum(trans, [])
    
    return Counter(trans)

def normalize_counter(counts):
    total = sum(counts.values(), 0)
    for key in counts:
        counts[key] /= total
    
    return counts

def top_k_acc(preds, targets, k=1):
    """
    preds has shape (n_examples, n_labels)
    targets has shape (n_examples, 1)
    """

    sorted_args = (-preds).argsort(axis=1)[:,:k]
    tt = np.tile(targets, (k,1)).T
    acc = np.mean(np.sum(sorted_args == tt, axis=1))
    return acc

def acc_df(preds, targets):
    ks = list(range(1,11))
    df_dict = {"model": [], "top_k": [], "value": []}

    for name, ps in preds.items():
        for k in ks:
            df_dict["model"].append(name)
            df_dict["top_k"].append(k)
            df_dict["value"].append(round(top_k_acc(ps, targets, k), 5)*100)
            
    return pd.DataFrame(df_dict)

def get_ngrams(n, tokens):    
    return [tuple(tokens[i:i+n]) for i in range(len(tokens)-n+1)]

def get_index(target, top_preds):    
    indices = np.where(top_preds == target)[0]
    if len(indices) == 0:
        return -1
    
    return indices[0]

# %% [markdown]
# ## Fetching the Results

# %%
df_path = "/data/rali7/Tmp/solimanz/data/pickles/excerpt-2017-02-20_reduced.pkl"
base_path = "/data/rali7/Tmp/solimanz/data/"
top550_path = os.path.join(base_path, "datasets", "top550")
reduced7000_path = os.path.join(base_path, "datasets", "reduced7000")
predictions_path = os.path.join(base_path, "model_predictions")

# %%
def get_generators(dataset="top550"):
    targets_path = os.path.join(predictions_path, dataset, "jobid", "targets")
    inputs_path = os.path.join(predictions_path, dataset, "jobid", "inputs")
    seq_lengths_path = os.path.join(predictions_path, dataset, "jobid", "seq_lengths")

    bow_predictions_path = os.path.join(predictions_path, dataset, "bow", "predictions")
    jobid_predictions_path = os.path.join(predictions_path, dataset, "jobid", "predictions")
    title_emb_predictions_path = os.path.join(predictions_path, dataset, "title_emb", "predictions")
    
    targets_gen = next_batch(targets_path)
    inputs_gen = next_batch(inputs_path)
    seq_length_gen = next_batch(seq_lengths_path)
    jobid_preds_gen = next_batch(jobid_predictions_path)
    bow_preds_gen = next_batch(bow_predictions_path)
    title_emb_preds_gen = next_batch(title_emb_predictions_path)
    
    return targets_gen, inputs_gen, seq_length_gen, jobid_preds_gen, bow_preds_gen, title_emb_preds_gen

# %%
with open(os.path.join(top550_path, "jobid", "data.json"), "r") as f:
    data = json.load(f)
#with open(os.path.join(reduced7000_path, "jobid", "data.json"), "r") as f:
#    data = json.load(f)

# %%
nb_preds_path = "/data/rali7/Tmp/solimanz/data/baseline_preds/best/multi_nb-preds.npy"
nb_targets_path = "/data/rali7/Tmp/solimanz/data/baseline_preds/best/multi_nb-targets.npy"

# %%
targets_path = os.path.join(predictions_path, "top550", "jobid", "targets")
inputs_path = os.path.join(predictions_path, "top550", "jobid", "inputs")
seq_lengths_path = os.path.join(predictions_path, "top550", "jobid", "seq_lengths")

bow_predictions_path = os.path.join(predictions_path, "top550", "bow", "predictions")
jobid_predictions_path = os.path.join(predictions_path, "top550", "jobid", "predictions")
title_emb_predictions_path = os.path.join(predictions_path, "top550", "title_emb", "predictions")

# %%
targets_gen, inputs_gen, seq_length_gen, jobid_preds_gen, bow_preds_gen, title_emb_preds_gen = get_generators('top550')

# %%
targets = []
inputs = []
seq_lengths = []

jobid_preds = []
bow_preds = []
title_emb_preds = []

for i, t, sl, jobid, bow, title_emb in zip(inputs_gen,
                                           targets_gen,
                                           seq_length_gen,
                                           jobid_preds_gen,
                                           bow_preds_gen,
                                           title_emb_preds_gen):
    inputs.append(i)
    targets.append(t)
    seq_lengths.append(sl)
    
    jobid_preds.append(jobid.reshape((jobid.shape[1],jobid.shape[2], jobid.shape[3])))
    bow_preds.append(bow.reshape((bow.shape[1],bow.shape[2], bow.shape[3])))
    title_emb_preds.append(title_emb.reshape((title_emb.shape[1],title_emb.shape[2], title_emb.shape[3])))

# %%
preds = dict()

# %%
inputs = np.concatenate(inputs, axis=0)
targets = np.concatenate(targets, axis=0)
seq_lengths = np.concatenate(seq_lengths, axis=0)
preds["jobid"] = np.concatenate(jobid_preds, axis=0)
preds["bow"] = np.concatenate(bow_preds, axis=0)
preds["fasttext"] = np.concatenate(title_emb_preds, axis=0)

# %%
z = np.zeros((preds["bow"].shape[0], 1, preds["bow"].shape[2]))
preds["bow"] = np.concatenate([preds["bow"], z], axis=1)
del z

# %%
nb_preds = np.load(nb_preds_path)
nb_targets = np.load(nb_targets_path)

# %%
xs = to_python_lists(inputs, seq_lengths)
ys = to_python_lists(targets, seq_lengths)
preds["jobid"] = to_python_lists(preds["jobid"], seq_lengths)
preds["bow"] = to_python_lists(preds["bow"], seq_lengths)
preds["fasttext"] = to_python_lists(preds["fasttext"], seq_lengths)

# %%
del jobid_preds
del title_emb_preds
del bow_preds

# %% [markdown]
# ### Focus Analysis on Last Output

# %%
ys = np.array([np.argmax(seq[-1], axis=0) for seq in ys])
preds["jobid"] = [seq[-1] for seq in preds["jobid"]]
preds["bow"] = [seq[-1] for seq in preds["bow"]]
preds["fasttext"] = [seq[-1] for seq in preds["fasttext"]]

# %%
preds["nb"] = nb_preds

# %%
for k, v in preds.items():
    if k != "nb":
        preds[k] = np.array(preds[k])

# %% [markdown]
# ## Distribution of Labels and Transitions in Training Set

# %%
train = data["train_data"]
test = data["test_data"]
title_to_id = bidict(data["title_to_id"])

test_inputs = [[str(i) for i in seq[:-1]] for seq in test]
test_targets = [seq[-1] for seq in test]

#train = [[title_to_id.inv[i] for i in seq] for seq in train]
#test = [[title_to_id.inv[i] for i in seq] for seq in test]

# %% [markdown]
# ### KenLM

# %%
def kenlm_predict(test, model_binary='train_bigram.binary'):    
    model = kenlm.Model(f"../../kenlm/build/{model_binary}")
    model_preds = np.zeros((len(test), 550))
    
    if model_binary == 'train_bigram.binary':
        n = 2
    elif model_binary == 'train_trigram.binary':
        n = 3
    elif model_binary == 'train_4gram.binary':
        n = 4
    elif model_binary == 'train_5gram.binary':
        n = 5
        
    for j, seq in enumerate(test):
        test_seq = seq[-(n-1):]
        for i in range(550):
            model_preds[j][i] = model.score(" ".join(test_seq + [str(i)]))
            
    return model_preds

# %%
preds['bigram'] = kenlm_predict(test_inputs, model_binary='train_bigram.binary')
preds['trigram'] = kenlm_predict(test_inputs, model_binary='train_trigram.binary')
preds['4gram'] = kenlm_predict(test_inputs, model_binary='train_4gram.binary')
preds['5gram'] = kenlm_predict(test_inputs, model_binary='train_5gram.binary')

# %% [markdown]
# ### "Most Common" Predictor

# %%
def train_most_common(sequences, max_n=4):
    ngrams = []
    for seq in sequences:
        for n in range(2, max_n + 1):
            ngrams += get_ngrams(n, seq)
    
    possible_transitions = defaultdict(list)
    ngram_counts = Counter(ngrams)
    
    for ngram, count in ngram_counts.most_common(len(ngram_counts)):
        target = ngram[-1]
        prev_steps = ngram[:-1]
        possible_transitions[prev_steps].append(target)
    
    return ngram_counts, {k: np.array(v) for k, v in possible_transitions.items()}

# %%
def test_most_common(model, test_seqs, k=1):
    predictions = []
    #max_n = max([len(ngram) for ngram in model.keys()])
    
    for seq in test_seqs:
        for i in reversed(range(len(seq))):
            ngram = tuple(seq[-i:])
            if ngram in model:
                predictions.append(model[ngram][k-1])
                break
    
    return predictions

# %%
def predict(model, test, n=2):    
    ngram_model_preds = np.zeros((len(test), 550))
    
    for j, seq in enumerate(test):
        ngram = tuple(seq[-(n-1):])
        for i in range(550):
            ngram_model_preds[j][i] = model.prob(ngram + (i,'<eos>'))
    return ngram_model_preds

def train_ngram_model(train_seqs, n=3):    
    seq_ngrams = sum([list(ngrams(seq, n, pad_right=True, right_pad_symbol='<eos>')) for seq in train_seqs], [])
    freq_dist = nltk.FreqDist(seq_ngrams)
    kneser_ney = nltk.KneserNeyProbDist(freq_dist)
    
    return kneser_ney, seq_ngrams

# %%
model, sng = train_ngram_model(train)

# %%
preds["fasttext"].shape
# Out:
# (24080, 32, 550)

# %%
preds["lm_bigram"] = predict(model, test_inputs)

# %% [markdown]
# ## Distribution of Sequence Lengths in Test Dataset

# %%
train_lengths = [len(t)-1 for t in train]
counts = Counter(train_lengths)
counts = normalize_counter(counts)

# %%
plt.rcParams['figure.figsize'] = 10, 5
plt.rcParams['figure.dpi'] = 150
ax = sns.barplot(x=list(counts.keys()), y=list(counts.values()))
plt.title("Distribution of Lenght of Job History")
plt.xlabel("Length (number of job/positions held)")
plt.ylabel("Frequency")
# Out:
# Text(0,0.5,'Frequency')

# %%
counts = normalize_counter(Counter(seq_lengths))
unormalized_counts = Counter(seq_lengths)
data = sorted([t for t in counts.items()], key=lambda x: x[0])

# %%
unormalized_counts
# Out:
# Counter({2: 14644,
#          3: 5813,
#          4: 2226,
#          5: 823,
#          6: 329,
#          7: 125,
#          8: 62,
#          9: 30,
#          10: 6,
#          11: 9,
#          12: 5,
#          13: 1,
#          14: 4,
#          16: 2,
#          17: 1})

# %%
df = pd.DataFrame({"length": [x[0] for x in data], "frequency": [x[1] for x in data]})

# %%
plt.rcParams['figure.figsize'] = 10, 5
plt.rcParams['figure.dpi'] = 180
plt.bar(x=[x[0] for x in data], height=[x[1] for x in data])
plt.title("Distribution of Lenght of Job History")
plt.xlabel("Length (number of job/positions held)")
plt.ylabel("Frequency")
# Out:
# Text(0,0.5,'Frequency')

# %% [markdown]
# ## Accuracy by length of sequence

# %%
df = topK_accs_df(preds, ys, seq_lengths)

# %%
def transform(s):
    if s == "bow":
        return "bow_lstm"
    elif s == "jobid":
        return "jobid_lstm"
    elif s == "nb":
        return "Multinomial naive bayes"
    elif s == "title_emb":
        return "title_emb_lstm"
    else:
        return s

df["model"] = df["model"].apply(transform)

# %%
df.acc = df.acc.apply(lambda x: x/100)

# %%
df = df[df.model.isin(["bigram", "fasttext", "Multinomial naive bayes"])]

# %%
plt.rcParams["figure.figsize"] = 2, 7
plt.rcParams["figure.dpi"] = 180

ggplot(aes(x='length', y='acc', color='model'), data=df[df.length <= 9]) \
+ geom_point(size=100, alpha=0.5) \
+ scale_y_continuous(breaks=[30, 35, 40, 45, 50, 55, 60, 65],
                     labels=['30%', '35%', '40%', '45%', '50%', '55%', '60%', '65%']) \
+ geom_line() \
+ xlab("Length of Job History") \
+ ylab("Accuracy") \
+ ggtitle("Accuracy Results Based on Length of Job History on the Top550 Dataset")
# Out:
# <ggplot: (-9223363281788660280)>

# %%
accs = acc_df(preds, ys)
accs.model = accs.model.apply(transform)

# %%
ggplot(aes(x='top_k', y='value', color='model'), data=accs[accs.model.isin(["bigram", "trigram", "4gram", "5gram"])]) \
+ geom_point(size=100, alpha=0.5) \
+ geom_line() \
+ scale_y_continuous(breaks=[30, 35, 40, 45, 50, 55, 60, 65],
                     labels=['30%', '35%', '40%', '45%', '50%', '55%', '60%', '65%']) \
+ xlab("Top K predictions") \
+ ylab("Accuracy") \
+ ggtitle("Top K Accuracy Results for N-gram Models on the Top550 Dataset")
# Out:
# <ggplot: (-9223363281787305391)>

# %%
ggplot(aes(x='top_k', y='value', color='model'), data=accs[accs.model.isin(["bow_lstm", "jobid_lstm", "fasttext"])]) \
+ geom_point(size=100, alpha=0.5) \
+ geom_line() \
+ scale_y_continuous(breaks=[30, 35, 40, 45, 50, 55, 60, 65],
                     labels=['30%', '35%', '40%', '45%', '50%', '55%', '60%', '65%']) \
+ xlab("Top K predictions") \
+ ylab("Accuracy") \
+ ggtitle("Top K Accuracy Results for Neuronal Models on the Top550 Dataset")
# Out:
# <ggplot: (-9223363281781740961)>

# %%
accs = accs[accs.model.isin(["bigram", "fasttext", "Multinomial naive bayes"])]

# %%
ggplot(aes(x='top_k', y='value', color='model'), data=accs) \
+ geom_point(size=100, alpha=0.5) \
+ geom_line() \
+ scale_y_continuous(breaks=[30, 35, 40, 45, 50, 55, 60, 65],
                     labels=['30%', '35%', '40%', '45%', '50%', '55%', '60%', '65%']) \
+ xlab("Top K predictions") \
+ ylab("Accuracy") \
+ ggtitle("Top K Accuracy Results for Best Performing Prediction Models on the Top550 Dataset")
# Out:
# <ggplot: (-9223363281788294396)>

# %% [markdown]
# ## Frequency of change Through time

# %%
by_length = defaultdict(list)
for seq in train:
    by_length[len(seq)].append(get_ngrams(2, seq))

# %%
seqs_trans = [get_ngrams(2, seq) for seq in train]

# %%
max([len(s) for s in test])
# Out:
# 18

# %%
change_freq = {}
totals = {}

for i in range(31):
    changed = 0.0
    total = 0.0
    
    for seq in seqs_trans:
        if i < len(seq):
            total += 1
            trans = seq[i]
            if trans[0] != trans[1]:
                changed += 1
                
    change_freq[i+1] = changed/total
    totals[i+1] = total

# %%
x = []
y = []

for k, v in change_freq.items():
    x.append(k)
    y.append(v)

# %%
plt.bar(x, y)
plt.title("Frequency of Job Title Change Through Time")
plt.ylabel("Frequency")
plt.xlabel("Job Timeline")
# Out:
# Text(0.5,0,'Job Timeline')

# %%
targets_by_length = dict()

for i in range(2, 19):
    selection = [seq for seq in test if len(seq) == i]
    targets_by_length[i] = [seq[-1] for seq in selection]

# %%
label_counts = Counter([seq[-1] for seq in train])
label_counts = normalize_counter(label_counts)
data = sorted([t for t in label_counts.items()], key=lambda x: x[0])

# %%
plt.rcParams['figure.figsize'] = 15, 15
plt.rcParams['figure.dpi'] = 180

lengths = [3,4,5,6,7,9,10]
f, axarr = plt.subplots(len(lengths), sharex=True)

for i, length in enumerate(lengths):
    axarr[i].plot([t[0] for t in data],[t[1] for t in data])
    for target in targets_by_length[length]:
        axarr[i].axvspan(target,target, color='red', alpha=0.5)
    axarr[i].set_title(f'Highlighting Prediction Targets for Sequences of Length {length-1}')

# %%
data = sorted(data, key=lambda t: t[0])

# %%
plt.rcParams['figure.figsize'] = 15, 5
plt.rcParams['figure.dpi'] = 180
plt.plot([t[0] for t in data],[t[1] for t in data])
plt.title("Distribution of Job Title Strings")
plt.ylabel("Frequency")
plt.xlabel("Unique Job Title ID Number")
# Out:
# Text(0.5,0,'Unique Job Title ID Number')

# %%
selection = [seq for seq in test if len(seq)==9]
selec_lst = [seq[-1] for seq in selection]

# %%
get_ngrams(2, train[9])
# Out:
# [(20, 20), (20, 342)]

# %%
transistions = []
for seq in train:
    transistions += get_ngrams(2, seq)

# %%
trans_counts = Counter(transistions)

# %%
transition_rankings = {t[0]: i + 1 for i, t in enumerate(trans_counts.most_common(len(trans_counts)))}

# %%
test_trans = [tuple(seq[-2:]) for seq in selection]

# %%
rankings = []

for t in test_trans:
    
    if t in transition_rankings:
        rankings.append(transition_rankings[t])
    else:
        rankings.append(-1)

# %% [markdown]
# ## Label Predictions

# %%
ordered_preds = dict()

for model, predictions in preds.items():
    ordered_preds[model] = [(-preds).argsort(axis=0)[:10]  for preds in predictions]

# %%
df_dict = defaultdict(list)

for model, topK_preds in ordered_preds.items():
    for i, predictions in enumerate(topK_preds):
        df_dict[f"{model}_pred"].append(predictions[0])
        df_dict[f"{model}_correct_at"].append(get_index(ys[i], preds))

df_dict["target"] = list(ys)
pred_df = pd.DataFrame(df_dict)

# %%
def get_confusion_matrix(targets, predicted, normalize=False):        
    cm = confusion_matrix(targets, predicted)    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    
    return cm

# %%
pred_df.columns
# Out:
# Index(['4gram_correct_at', '4gram_pred', '5gram_correct_at', '5gram_pred',
#        'bigram_correct_at', 'bigram_pred', 'bow_correct_at', 'bow_pred',
#        'fasttext_correct_at', 'fasttext_pred', 'jobid_correct_at',
#        'jobid_pred', 'nb_correct_at', 'nb_pred', 'target',
#        'trigram_correct_at', 'trigram_pred'],
#       dtype='object')

# %%
models = ['fasttext', 'nb', 'bigram']
colors = ['r', 'c', 'y']
#f, axarr = plt.subplots(len(models), sharex=True)
fig, ax = plt.subplots(figsize=(20, 5))

for model, color in zip(models, colors):
    cm = get_confusion_matrix(pred_df.target.values, pred_df[f'{model}_pred'].values, True)
    diag = cm.diagonal()
    
    ax.plot(range(len(diag)), diag, color, label=model, alpha=0.5)
    ax.legend()

# %%
cm = get_confusion_matrix(pred_df.target.values, pred_df.nb_pred.values, True)

# %%
diag = cm.diagonal()

# %%
plt.plot(range(len(diag)), diag)

# %%
seqs_trans = normalize_counter(Counter(sum([get_ngrams(2, seq) for seq in train], [])))

# %%
data = sorted([t for t in seqs_trans.items()], key=lambda x: x[1])

# %%
correct_trans = [tuple(seq[-2:]) for seq in test]

# %%
predicted_trans = dict()
for model in models:
    predicted_trans[model] = [(t[-2], p) for t, p in zip(test, pred_df[f'{model}_pred'].values)]

# %%
wrong_preds = defaultdict(list)

for model in models:
    for predicted, correct in zip(predicted_trans[model], correct_trans):
        if predicted != correct:
            wrong_preds[model].append(predicted)

# %%
len(seqs_trans)
# Out:
# 42712

# %%
most_common = dict()

for trans, freq in seqs_trans.most_common(len(seqs_trans)):
    if trans[0] not in most_common:
        most_common[trans[0]] = trans[1]

# %%
most_common = set(most_common.items())

# %%
is_most_common = dict()

for model in models:
    is_most_common[model] = [p in most_common for p in wrong_preds[model]]

# %%
for model in models:
    p = sum(is_most_common[model])/len(is_most_common[model])
    print(f"{p*100:.2f}% of {model}'s prediction mistakes are the most commonly seen transition")
# Out:
# 59.60% of fasttext's prediction mistakes are the most commonly seen transition
# 51.06% of nb's prediction mistakes are the most commonly seen transition
# 95.86% of bigram's prediction mistakes are the most commonly seen transition

# %%
diff = pred_df[pred_df['nb_pred'] != pred_df['fasttext_pred']]

# %%
is_most_common.keys()
# Out:
# dict_keys(['fasttext', 'nb', 'bigram'])

# %%
for i, t, nb, ft in zip(diff.index.values,
                        diff.target.values,
                        diff.nb_pred.values,
                        diff.fasttext_pred.values):
    
    if is_most_common['nb'][i] or is_most_common['fasttext'][i]:
        continue
    if t != nb and t != ft:
        hist = " => ".join([title_to_id.inv[j] for j in test[i][:-1]])
        print(f"**({i})** {hist} => {title_to_id.inv[t]}\n")
        print(f"\t\tNaive Bayes: {title_to_id.inv[nb]}\n\t\tfasttext: {title_to_id.inv[ft]}\n")
# Out:
# **(48)** maintenance supervisor => production coordinator => quality assurance manager => retired
#
# 		Naive Bayes: maintenance supervisor
# 		fasttext: owner
#
# **(64)** credit analyst => accounts receivable clerk => credit analyst
#
# 		Naive Bayes: financial analyst
# 		fasttext: accounting clerk
#
# **(65)** business analyst => senior accountant => marketing manager => chief operating officer
#
# 		Naive Bayes: manager
# 		fasttext: accountant
#
# **(118)** tutor => accounting assistant => teaching assistant
#
# 		Naive Bayes: accountant
# 		fasttext: staff accountant
#
# **(124)** student => instructor => professor
#
# 		Naive Bayes: instructor
# 		fasttext: tutor
#
# **(195)** receptionist => sandwich artist => junior designer
#
# 		Naive Bayes: receptionist
# 		fasttext: cashier
#
# **(213)** sales associate => key holder => sales consultant
#
# 		Naive Bayes: sales associate
# 		fasttext: assistant manager
#
# **(216)** associate => salesperson => broker
#
# 		Naive Bayes: associate
# 		fasttext: salesperson
#
# **(245)** dispatcher => cashier => accounting assistant
#
# 		Naive Bayes: dispatcher
# 		fasttext: customer service representative
#
# **(295)** sales => sales => territory manager => sales => territory manager => account executive => territory manager
#
# 		Naive Bayes: sales
# 		fasttext: sales representative
#
# **(312)** sales => assistant project manager => project assistant
#
# 		Naive Bayes: sales
# 		fasttext: project manager
#
# **(337)** staff accountant => senior accountant => senior financial analyst
#
# 		Naive Bayes: senior accountant
# 		fasttext: manager
#
# **(355)** cashier => retail sales associate => assistant manager
#
# 		Naive Bayes: cashier
# 		fasttext: retail sales associate
#
# **(371)** summer student => customer service => sales associate
#
# 		Naive Bayes: associate
# 		fasttext: summer student
#
# **(381)** crew member => assistant manager => general manager
#
# 		Naive Bayes: sales associate
# 		fasttext: manager
#
# **(387)** accountant => accountant => accountant => financial analyst => senior financial analyst
#
# 		Naive Bayes: accountant
# 		fasttext: financial analyst
#
# **(458)** management trainee => sales associate => customer service representative
#
# 		Naive Bayes: assistant manager
# 		fasttext: sales associate
#
# **(463)** owner => branch manager => district sales manager
#
# 		Naive Bayes: owner
# 		fasttext: branch manager
#
# **(503)** senior accountant => senior accountant => owner
#
# 		Naive Bayes: senior accountant
# 		fasttext: controller
#
# **(504)** associate => business development => intern => production assistant
#
# 		Naive Bayes: associate
# 		fasttext: account executive
#
# **(517)** instructor => instructor => lecturer => manager => founder
#
# 		Naive Bayes: instructor
# 		fasttext: professor
#
# **(530)** programmer => web developer => developer => senior developer
#
# 		Naive Bayes: software developer
# 		fasttext: developer
#
# **(541)** business development manager => managing director => associate
#
# 		Naive Bayes: managing director
# 		fasttext: director
#
# **(542)** owner/manager => technician => material handler => technician
#
# 		Naive Bayes: owner/manager
# 		fasttext: truck driver
#
# **(552)** senior manager => senior manager => chief finance officer
#
# 		Naive Bayes: partner
# 		fasttext: senior manager
#
# **(619)** summer student => summer student => research associate
#
# 		Naive Bayes: associate
# 		fasttext: summer student
#
# **(620)** senior manager => corporate controller => corporate controller => controller
#
# 		Naive Bayes: chief finance officer
# 		fasttext: vice president finance
#
# **(632)** president => financial analyst => consultant
#
# 		Naive Bayes: president
# 		fasttext: financial analyst
#
# **(655)** assistant manager => owner operator => labourer => accounting clerk => junior accountant
#
# 		Naive Bayes: manager
# 		fasttext: accounting clerk
#
# **(701)** human resources assistant => human resources assistant => human resources assistant
#
# 		Naive Bayes: human resources generalist
# 		fasttext: human resources coordinator
#
# **(717)** financial services manager => financial advisor => board member => board member
#
# 		Naive Bayes: financial planner
# 		fasttext: director
#
# **(722)** senior buyer => sales => branch manager
#
# 		Naive Bayes: sales
# 		fasttext: buyer
#
# **(734)** teacher => general manager => director
#
# 		Naive Bayes: teacher
# 		fasttext: general manager
#
# **(786)** graphic designer => president => president
#
# 		Naive Bayes: owner
# 		fasttext: graphic designer
#
# **(845)** marketing assistant => marketing assistant => administrator
#
# 		Naive Bayes: marketing coordinator
# 		fasttext: marketing assistant
#
# **(924)** manager => research associate => senior financial analyst
#
# 		Naive Bayes: manager
# 		fasttext: research assistant
#
# **(934)** general manager => cashier => supervisor => trainee => trainee
#
# 		Naive Bayes: supervisor
# 		fasttext: intern
#
# **(938)** associate => analyst => account manager => commercial account manager
#
# 		Naive Bayes: associate
# 		fasttext: account executive
#
# **(946)** staff accountant => senior accountant => accounting manager
#
# 		Naive Bayes: senior accountant
# 		fasttext: manager
#
# **(950)** general manager => administrative assistant => office manager
#
# 		Naive Bayes: general manager
# 		fasttext: administrative assistant
#
# **(1130)** hairstylist => hairstylist => hairstylist => educator => owner
#
# 		Naive Bayes: hairstylist
# 		fasttext: teacher
#
# **(1156)** administrative assistant => volunteer => accounting clerk => bookkeeper
#
# 		Naive Bayes: administrative assistant
# 		fasttext: accounting clerk
#
# **(1168)** intern => server/bartender => clerk => server
#
# 		Naive Bayes: intern
# 		fasttext: sales associate
#
# **(1197)** accounting assistant => technician => machine operator
#
# 		Naive Bayes: technician
# 		fasttext: accounting assistant
#
# **(1218)** sales representative => assistant manager => accounting assistant
#
# 		Naive Bayes: sales representative
# 		fasttext: store manager
#
# **(1242)** brand ambassador => bartender/server => business development => account manager
#
# 		Naive Bayes: brand ambassador
# 		fasttext: bartender/server
#
# **(1246)** sales representative => server => volunteer
#
# 		Naive Bayes: sales representative
# 		fasttext: server
#
# **(1255)** account manager => sales representative => territory manager
#
# 		Naive Bayes: account manager
# 		fasttext: sales representative
#
# **(1257)** logistics coordinator => logistics manager => account manager
#
# 		Naive Bayes: logistics coordinator
# 		fasttext: operations manager
#
# **(1275)** general manager => business manager => realtor
#
# 		Naive Bayes: general manager
# 		fasttext: owner
#
# **(1282)** founder => controller => finance manager => accounting manager => finance manager
#
# 		Naive Bayes: controller
# 		fasttext: accounting manager
#
# **(1308)** marketing manager => director => partner
#
# 		Naive Bayes: director
# 		fasttext: president
#
# **(1346)** sales associate => receptionist => office manager
#
# 		Naive Bayes: sales associate
# 		fasttext: receptionist
#
# **(1359)** branch manager => customer service representative => inside sales representative => outside sales representative
#
# 		Naive Bayes: branch manager
# 		fasttext: customer service representative
#
# **(1369)** manager => sales associate => supervisor
#
# 		Naive Bayes: manager
# 		fasttext: sales associate
#
# **(1375)** technical consultant => vice president operations => manager
#
# 		Naive Bayes: consultant
# 		fasttext: vice president operations
#
# **(1424)** designer => design engineer => project engineer => senior project engineer
#
# 		Naive Bayes: project engineer
# 		fasttext: design engineer
#
# **(1442)** cook => office assistant => barista
#
# 		Naive Bayes: cook
# 		fasttext: sales associate
#
# **(1446)** sales representative => business development manager => area manager => senior consultant
#
# 		Naive Bayes: sales representative
# 		fasttext: district manager
#
# **(1470)** senior software engineer => technical specialist => consultant
#
# 		Naive Bayes: senior software engineer
# 		fasttext: technical specialist
#
# **(1543)** laboratory assistant => laboratory technician => quality assurance technician
#
# 		Naive Bayes: laboratory technician
# 		fasttext: research assistant
#
# **(1554)** various => vice president => vice president => senior vice president
#
# 		Naive Bayes: vice president
# 		fasttext: president
#
# **(1617)** assistant manager => accounts payable => accounting manager
#
# 		Naive Bayes: accountant
# 		fasttext: office manager
#
# **(1620)** system engineer => graduate teaching assistant => intern => graduate teaching assistant
#
# 		Naive Bayes: research assistant
# 		fasttext: programmer
#
# **(1656)** student => tutor => financial consultant
#
# 		Naive Bayes: research assistant
# 		fasttext: teacher
#
# **(1658)** hostess => assistant manager => service advisor
#
# 		Naive Bayes: sales associate
# 		fasttext: server
#
# **(1665)** manager => vice president => investment advisor
#
# 		Naive Bayes: president
# 		fasttext: vice president
#
# **(1683)** president => project assistant => executive assistant
#
# 		Naive Bayes: president
# 		fasttext: project coordinator
#
# **(1697)** president => owner => controller
#
# 		Naive Bayes: president
# 		fasttext: owner
#
# **(1771)** graduate student => assistant professor => machine operator
#
# 		Naive Bayes: associate professor
# 		fasttext: assistant professor
#
# **(1773)** customer service representative => bartender => junior accountant => server/bartender
#
# 		Naive Bayes: customer service representative
# 		fasttext: junior accountant
#
# **(1780)** director of sales => sales director => sales director
#
# 		Naive Bayes: sales manager
# 		fasttext: president
#
# **(1799)** general manager => construction manager => senior project manager => construction manager
#
# 		Naive Bayes: project manager
# 		fasttext: senior project manager
#
# **(1806)** internal auditor => senior accountant => student-at-law => associate lawyer => legal counsel
#
# 		Naive Bayes: partner
# 		fasttext: associate lawyer
#
# **(1809)** teacher => manager => director
#
# 		Naive Bayes: teacher
# 		fasttext: manager
#
# **(1815)** administrative assistant => receptionist => legal assistant => law clerk
#
# 		Naive Bayes: administrative assistant
# 		fasttext: legal assistant
#
# **(1828)** operations manager => customer service representative => administrative assistant
#
# 		Naive Bayes: operations manager
# 		fasttext: financial service representative
#
# **(1832)** customer service representative => owner/manager => owner/manager
#
# 		Naive Bayes: customer service representative
# 		fasttext: manager
#
# **(1862)** manager => managing partner => mortgage agent
#
# 		Naive Bayes: partner
# 		fasttext: managing partner
#
# **(1900)** cashier => bartender => customer service representative => receptionist
#
# 		Naive Bayes: customer service representative
# 		fasttext: supervisor
#
# **(1919)** sales associate => area sales manager => office administrator
#
# 		Naive Bayes: sales associate
# 		fasttext: area sales manager
#
# **(1960)** vice president => associate => investment advisor => financial advisor
#
# 		Naive Bayes: partner
# 		fasttext: investment advisor
#
# **(1966)** foreman => customer service => co owner
#
# 		Naive Bayes: owner
# 		fasttext: foreman
#
# **(1972)** project coordinator => financial service representative => credit analyst => credit analyst
#
# 		Naive Bayes: project coordinator
# 		fasttext: financial analyst
#
# **(1976)** owner/operator => teacher => occasional teacher
#
# 		Naive Bayes: teacher
# 		fasttext: owner/operator
#
# **(1985)** inside sales => financial services representative => area manager
#
# 		Naive Bayes: financial advisor
# 		fasttext: branch manager
#
# **(1989)** programmer analyst => instructor => programmer analyst => programmer analyst => senior software developer
#
# 		Naive Bayes: programmer analyst
# 		fasttext: systems analyst
#
# **(2026)** engineer in training => application developer => business systems analyst
#
# 		Naive Bayes: application developer
# 		fasttext: software developer
#
# **(2046)** sales representative => account manager => vice president => co founder
#
# 		Naive Bayes: account manager
# 		fasttext: president
#
# **(2088)** driver => truck driver => inside sales
#
# 		Naive Bayes: truck driver
# 		fasttext: driver
#
# **(2095)** customer service representative => cashier => logistics coordinator => logistics coordinator
#
# 		Naive Bayes: customer service representative
# 		fasttext: sales associate
#
# **(2103)** store manager => district manager => district sales manager
#
# 		Naive Bayes: store manager
# 		fasttext: district manager
#
# **(2216)** reporter => communications consultant => owner
#
# 		Naive Bayes: reporter
# 		fasttext: editor
#
# **(2228)** customer service representative => supervisor => pharmacy assistant
#
# 		Naive Bayes: customer service representative
# 		fasttext: assistant manager
#
# **(2259)** sales and marketing manager => regional sales manager => managing director
#
# 		Naive Bayes: sales manager
# 		fasttext: regional sales manager
#
# **(2298)** marketing intern => marketing associate => marketing assistant => marketing assistant
#
# 		Naive Bayes: marketing manager
# 		fasttext: marketing coordinator
#
# **(2304)** supervisor => banquet server => front desk agent
#
# 		Naive Bayes: supervisor
# 		fasttext: server
#
# **(2313)** social worker => counsellor => account executive
#
# 		Naive Bayes: social worker
# 		fasttext: counsellor
#
# **(2347)** general manager => managing director => president
#
# 		Naive Bayes: general manager
# 		fasttext: managing director
#
# **(2358)** national sales manager => sales manager => broker => director
#
# 		Naive Bayes: sales manager
# 		fasttext: broker
#
# **(2360)** sales clerk => customer service representative => financial advisor
#
# 		Naive Bayes: customer service representative
# 		fasttext: student ambassador
#
# **(2368)** senior financial analyst => general manager => event coordinator => director of finance
#
# 		Naive Bayes: general manager
# 		fasttext: manager
#
# **(2385)** facilitator => production manager => superintendent => financial advisor
#
# 		Naive Bayes: production manager
# 		fasttext: project manager
#
# **(2391)** senior buyer => president => founder
#
# 		Naive Bayes: president
# 		fasttext: buyer
#
# **(2425)** human resources assistant => human resources assistant => human resources assistant
#
# 		Naive Bayes: human resources generalist
# 		fasttext: human resources coordinator
#
# **(2441)** manager => vice president => vice president => sales manager => general manager => director => manager
#
# 		Naive Bayes: president
# 		fasttext: director
#
# **(2491)** student => account executive => sales manager => district manager
#
# 		Naive Bayes: account executive
# 		fasttext: sales manager
#
# **(2492)** senior engineer => project assistant => electrical engineer
#
# 		Naive Bayes: senior engineer
# 		fasttext: project manager
#
# **(2528)** owner => administrative assistant => graphic designer
#
# 		Naive Bayes: owner
# 		fasttext: administrative assistant
#
# **(2550)** customer service representative => assistant manager => office administrator
#
# 		Naive Bayes: customer service representative
# 		fasttext: assistant manager
#
# **(2579)** operations manager => district manager => key account manager
#
# 		Naive Bayes: operations manager
# 		fasttext: district manager
#
# **(2586)** administrative assistant => accounting assistant => office manager
#
# 		Naive Bayes: administrative assistant
# 		fasttext: junior accountant
#
# **(2596)** programmer analyst => systems analyst => analyst
#
# 		Naive Bayes: systems analyst
# 		fasttext: senior systems analyst
#
# **(2612)** secretary => instructor => receptionist => communications coordinator => cashier => medical office assistant
#
# 		Naive Bayes: receptionist
# 		fasttext: administrative assistant
#
# **(2630)** manager => administrative assistant => manager => executive assistant
#
# 		Naive Bayes: manager
# 		fasttext: administrative assistant
#
# **(2661)** actor => freelancer writer => lab technician
#
# 		Naive Bayes: actor
# 		fasttext: teacher
#
# **(2666)** executive assistant => sales representative => human resources assistant => marketing assistant
#
# 		Naive Bayes: executive assistant
# 		fasttext: human resources coordinator
#
# **(2670)** human resources => operations supervisor => human resources generalist => director, human resources
#
# 		Naive Bayes: human resources manager
# 		fasttext: human resources generalist
#
# **(2722)** supervisor => information technology specialist => information technology specialist
#
# 		Naive Bayes: supervisor
# 		fasttext: information technology consultant
#
# **(2763)** president & chief executive officer => president & chief executive officer => director => president
#
# 		Naive Bayes: president & chief executive officer
# 		fasttext: director
#
# **(2765)** owner => accountant => controller
#
# 		Naive Bayes: owner
# 		fasttext: accountant
#
# **(2809)** assistant manager => customer service representative => business development => account executive
#
# 		Naive Bayes: customer service representative
# 		fasttext: sales representative
#
# **(2826)** brand ambassador => sales representative => sales associate => director => owner
#
# 		Naive Bayes: sales representative
# 		fasttext: director
#
# **(2862)** president => chair => vice president
#
# 		Naive Bayes: president
# 		fasttext: director
#
# **(2882)** chief finance officer => executive vice president => chief operating officer => chief operating officer => president and chief executive officer
#
# 		Naive Bayes: chief executive officer
# 		fasttext: chief operating officer
#
# **(2897)** research coordinator => research assistant => research engineer => project engineer
#
# 		Naive Bayes: research assistant
# 		fasttext: teaching assistant
#
# **(2924)** store manager => project manager => assistant manager => assistant manager
#
# 		Naive Bayes: general manager
# 		fasttext: store manager
#
# **(2950)** sandwich artist => administrative assistant => marketing assistant => marketing assistant
#
# 		Naive Bayes: administrative assistant
# 		fasttext: customer service representative
#
# **(2979)** junior designer => summer student => intern architect
#
# 		Naive Bayes: associate
# 		fasttext: summer student
#
# **(3000)** laboratory assistant => laboratory technician => research assistant => teaching assistant => quality assurance specialist => technical director
#
# 		Naive Bayes: research assistant
# 		fasttext: quality assurance analyst
#
# **(3024)** chief executive officer => president => board member
#
# 		Naive Bayes: chief executive officer
# 		fasttext: president
#
# **(3034)** teaching assistant => sales => bartender => manager
#
# 		Naive Bayes: sales
# 		fasttext: bartender
#
# **(3055)** volunteer => research coordinator => co founder => project coordinator => project manager
#
# 		Naive Bayes: volunteer
# 		fasttext: project coordinator
#
# **(3087)** account coordinator => sales representative => receptionist
#
# 		Naive Bayes: account manager
# 		fasttext: sales representative
#
# **(3100)** sales associate => buyer => senior buyer
#
# 		Naive Bayes: sales associate
# 		fasttext: buyer
#
# **(3146)** labourer => sales associate => human resources generalist => consultant => coach
#
# 		Naive Bayes: labourer
# 		fasttext: sales associate
#
# **(3191)** accountant => intermediate accountant => senior business analyst => financial analyst
#
# 		Naive Bayes: accountant
# 		fasttext: senior financial analyst
#
# **(3202)** structural engineer => field engineer => director
#
# 		Naive Bayes: structural engineer
# 		fasttext: field engineer
#
# **(3227)** national account manager => regional manager => regional sales manager => sales manager => director of business development
#
# 		Naive Bayes: sales manager
# 		fasttext: account manager
#
# **(3315)** teaching assistant => teaching assistant => research assistant => research intern
#
# 		Naive Bayes: research assistant
# 		fasttext: teaching assistant
#
# **(3319)** intern => intern => marketing coordinator => product manager
#
# 		Naive Bayes: intern
# 		fasttext: marketing coordinator
#
# **(3339)** server => bartender => financial services representative => bookkeeper
#
# 		Naive Bayes: server
# 		fasttext: financial advisor
#
# **(3348)** production supervisor => pharmacist => peer tutor
#
# 		Naive Bayes: production supervisor
# 		fasttext: pharmacist
#
# **(3357)** project coordinator => researcher => research assistant
#
# 		Naive Bayes: project coordinator
# 		fasttext: researcher
#
# **(3388)** produce clerk => cashier/customer service => apprentice electrician
#
# 		Naive Bayes: cashier
# 		fasttext: cashier/customer service
#
# **(3489)** administrator assistant => human resources assistant => analyst
#
# 		Naive Bayes: executive assistant
# 		fasttext: human resources coordinator
#
# **(3501)** program manager => producer => teacher
#
# 		Naive Bayes: executive director
# 		fasttext: owner
#
# **(3562)** server => front desk receptionist => brand ambassador => waitress => treasurer
#
# 		Naive Bayes: server
# 		fasttext: customer service representative
#
# **(3577)** sales representative => account executive => business development manager => managing director
#
# 		Naive Bayes: account executive
# 		fasttext: account manager
#
# **(3641)** assistant manager => general manager => department manager => district manager => general manager
#
# 		Naive Bayes: store manager
# 		fasttext: district manager
#
# **(3665)** graduate research assistant => teaching assistant => senior associate
#
# 		Naive Bayes: teaching assistant
# 		fasttext: research assistant
#
# **(3690)** cashier => customer service agent => hostess
#
# 		Naive Bayes: customer service representative
# 		fasttext: customer service agent
#
# **(3764)** owner => restaurant manager => restaurant manager
#
# 		Naive Bayes: owner
# 		fasttext: general manager
#
# **(3769)** graduate research assistant => teaching assistant => software engineer
#
# 		Naive Bayes: teaching assistant
# 		fasttext: research assistant
#
# **(3793)** department manager => shipper/receiver => manager => customer service representative
#
# 		Naive Bayes: store manager
# 		fasttext: manager
#
# **(3821)** assistant manager => sales manager => sales representative
#
# 		Naive Bayes: store manager
# 		fasttext: general manager
#
# **(3850)** student => marketing => independent consultant
#
# 		Naive Bayes: student
# 		fasttext: marketing manager
#
# **(3894)** teacher => teacher => project manager => instructor
#
# 		Naive Bayes: teacher
# 		fasttext: project manager
#
# **(3897)** team leader => sales associate => supervisor => practicum student
#
# 		Naive Bayes: supervisor
# 		fasttext: sales associate
#
# **(3900)** manager => vice president => managing director => general manager => sales manager
#
# 		Naive Bayes: president
# 		fasttext: general manager
#
# **(3915)** marketing associate => administrative assistant => financial advisor => sales manager => staff accountant => customer service representative
#
# 		Naive Bayes: financial advisor
# 		fasttext: staff accountant
#
# **(3945)** server/bartender => client service representative => customer service representative
#
# 		Naive Bayes: server/bartender
# 		fasttext: administrative assistant
#
# **(3947)** owner/manager => warehouse supervisor => financial advisor
#
# 		Naive Bayes: owner/manager
# 		fasttext: warehouse supervisor
#
# **(3974)** cook => sous chef => chef => line cook => technician
#
# 		Naive Bayes: chef
# 		fasttext: sous chef
#
# **(3975)** engineer => senior engineer => director => director
#
# 		Naive Bayes: engineer
# 		fasttext: senior engineer
#
# **(3979)** owner => account manager => communications officer
#
# 		Naive Bayes: owner
# 		fasttext: account manager
#
# **(4020)** dishwasher => banquet server => server
#
# 		Naive Bayes: general labourer
# 		fasttext: cashier
#
# **(4032)** receptionist => team member => team member
#
# 		Naive Bayes: receptionist
# 		fasttext: sales associate
#
# **(4035)** administration => administrator => account manager
#
# 		Naive Bayes: administrator
# 		fasttext: administration
#
# **(4037)** manager => financial analyst => controller
#
# 		Naive Bayes: manager
# 		fasttext: financial analyst
#
# **(4058)** partner => co founder => director
#
# 		Naive Bayes: partner
# 		fasttext: owner
#
# **(4084)** software developer => software engineer => software engineer => software engineer => senior software engineer => senior software engineer => senior software engineer => senior software engineer => software developer => software developer
#
# 		Naive Bayes: senior software engineer
# 		fasttext: software engineer
#
# **(4118)** cashier => waitress => administrator => receptionist
#
# 		Naive Bayes: waitress
# 		fasttext: cashier
#
# **(4124)** member => cashier => assistant manager => visual merchandiser => store manager
#
# 		Naive Bayes: assistant manager
# 		fasttext: customer service representative
#
# **(4205)** teaching assistant => teaching assistant => research assistant => private tutor
#
# 		Naive Bayes: research assistant
# 		fasttext: teaching assistant
#
# **(4217)** supervisor => photographer => machine operator
#
# 		Naive Bayes: owner
# 		fasttext: photographer
#
# **(4218)** programmer => computer technician => manager => application developer
#
# 		Naive Bayes: software developer
# 		fasttext: manager
#
# **(4227)** programmer analyst => software engineer => system analyst => information technology manager
#
# 		Naive Bayes: software engineer
# 		fasttext: system analyst
#
# **(4252)** chief executive officer => researcher => researcher
#
# 		Naive Bayes: chief executive officer
# 		fasttext: director
#
# **(4310)** design engineer => software engineer => consultant => business consultant
#
# 		Naive Bayes: software engineer
# 		fasttext: consultant
#
# **(4314)** customer service representative => director => secretary
#
# 		Naive Bayes: director
# 		fasttext: customer service representative
#
# **(4328)** sessional instructor => technical support representative => technical support representative => technical support representative => technical support representative => instructor
#
# 		Naive Bayes: technical support representative
# 		fasttext: business analyst
#
# **(4333)** sales clerk => office manager => clerk
#
# 		Naive Bayes: office manager
# 		fasttext: sales associate
#
# **(4360)** sales assistant => sales associate => sales representative => sales
#
# 		Naive Bayes: sales associate
# 		fasttext: sales representative
#
# **(4361)** sales representative => sales representative => administrative assistant => sales
#
# 		Naive Bayes: sales representative
# 		fasttext: administrative assistant
#
# **(4387)** caregiver => educational assistant => independent consultant
#
# 		Naive Bayes: personal support worker
# 		fasttext: educational assistant
#
# **(4414)** legal counsel => teacher => real estate broker
#
# 		Naive Bayes: teacher
# 		fasttext: owner
#
# **(4425)** pharmacist => pharmacist => research assistant => lab technician
#
# 		Naive Bayes: pharmacist
# 		fasttext: research assistant
#
# **(4448)** superintendent => security guard => general labourer => superintendent
#
# 		Naive Bayes: security guard
# 		fasttext: general labourer
#
# **(4470)** receptionist => cashier => assistant manager
#
# 		Naive Bayes: receptionist
# 		fasttext: cashier
#
# **(4554)** vice president => manager => assistant manager
#
# 		Naive Bayes: president
# 		fasttext: owner
#
# **(4559)** production coordinator => production manager => producer => producer
#
# 		Naive Bayes: production manager
# 		fasttext: associate producer
#
# **(4600)** financial controller => manager => financial controller => director of finance => principal
#
# 		Naive Bayes: director of finance
# 		fasttext: financial controller
#
# **(4657)** laboratory assistant => pharmacy assistant => administrative assistant
#
# 		Naive Bayes: pharmacy assistant
# 		fasttext: pharmacy technician
#
# **(4702)** office manager => financial advisor => account manager
#
# 		Naive Bayes: financial advisor
# 		fasttext: customer service representative
#
# **(4730)** associate => vice president => vice president
#
# 		Naive Bayes: partner
# 		fasttext: director
#
# **(4732)** senior software developer => senior developer => developer
#
# 		Naive Bayes: senior software developer
# 		fasttext: senior developer
#
# **(4745)** sales representative => customer service representative => operations manager
#
# 		Naive Bayes: sales representative
# 		fasttext: customer service representative
#
# **(4770)** cashier => laboratory technician => accounting assistant
#
# 		Naive Bayes: student
# 		fasttext: laboratory technician
#
# **(4783)** team leader => assistant manager => sales associate => assistant store manager
#
# 		Naive Bayes: assistant manager
# 		fasttext: store manager
#
# **(4793)** bookkeeper => receptionist => sales representative
#
# 		Naive Bayes: bookkeeper
# 		fasttext: receptionist
#
# **(4805)** manager => consultant => teacher
#
# 		Naive Bayes: manager
# 		fasttext: consultant
#
# **(4814)** vice president finance => programmer => bookkeeper
#
# 		Naive Bayes: programmer
# 		fasttext: chief finance officer
#
# **(4826)** office manager => outside sales representative => inside sales representative
#
# 		Naive Bayes: office manager
# 		fasttext: sales representative
#
# **(4846)** assistant manager => manager => office manager => bilingual customer service representative => marketing manager => director
#
# 		Naive Bayes: manager
# 		fasttext: customer service representative
#
# **(4855)** manager => manager => hostess => sandwich artist => barista
#
# 		Naive Bayes: manager
# 		fasttext: cashier
#
# **(4867)** vice president => president => territory manager => district manager => district manager => retired
#
# 		Naive Bayes: president
# 		fasttext: district manager
#
# **(4921)** assistant manager => laboratory technician => logistics coordinator => laboratory technician
#
# 		Naive Bayes: assistant manager
# 		fasttext: project coordinator
#
# **(4926)** graduate student => teaching assistant => research coordinator
#
# 		Naive Bayes: teaching assistant
# 		fasttext: research assistant
#
# **(4936)** branch manager => executive vice president => owner
#
# 		Naive Bayes: branch manager
# 		fasttext: president
#
# **(4945)** accountant => intermediate accountant => intermediate accountant
#
# 		Naive Bayes: accountant
# 		fasttext: senior accountant
#
# **(4964)** sales executive => senior manager => sales associate
#
# 		Naive Bayes: senior manager
# 		fasttext: vice president
#
# **(4981)** office manager => customer service representative => administrative assistant
#
# 		Naive Bayes: office manager
# 		fasttext: customer service representative
#
# **(4985)** executive director => sales manager => manager
#
# 		Naive Bayes: executive director
# 		fasttext: sales manager
#
# **(4994)** customer service representative => data entry clerk => cashier
#
# 		Naive Bayes: customer service representative
# 		fasttext: administrative assistant
#
# **(4996)** policy analyst => research associate => communications coordinator => associate
#
# 		Naive Bayes: assistant professor
# 		fasttext: project manager
#
# **(5058)** server => sales associate => hostess => office assistant => receptionist => cashier => office assistant
#
# 		Naive Bayes: sales associate
# 		fasttext: customer service representative
#
# **(5068)** account manager => receptionist/administrative assistant => receptionist/administrative assistant
#
# 		Naive Bayes: account manager
# 		fasttext: administrative assistant
#
# **(5073)** summer student => staff accountant => senior accountant
#
# 		Naive Bayes: staff accountant
# 		fasttext: senior staff accountant
#
# **(5091)** hostess => cashier => marketing coordinator
#
# 		Naive Bayes: cashier
# 		fasttext: server
#
# **(5156)** manager => trainer => teacher
#
# 		Naive Bayes: owner
# 		fasttext: manager
#
# **(5184)** sales associate => sales associate => customer service representative => student
#
# 		Naive Bayes: sales associate
# 		fasttext: customer service representative
#
# **(5203)** manager => assistant manager => sales associate
#
# 		Naive Bayes: manager
# 		fasttext: assistant manager
#
# **(5241)** customer service supervisor => team lead => property manager => office manager
#
# 		Naive Bayes: team lead
# 		fasttext: property manager
#
# **(5253)** general manager => treasurer => vice president
#
# 		Naive Bayes: general manager
# 		fasttext: owner
#
# **(5283)** teacher => occasional teacher => teacher => occasional teacher => volunteer => support worker
#
# 		Naive Bayes: teacher
# 		fasttext: occasional teacher
#
# **(5345)** housekeeper => owner => cook
#
# 		Naive Bayes: owner
# 		fasttext: cashier
#
# **(5369)** lawyer => president => co founder
#
# 		Naive Bayes: partner
# 		fasttext: president
#
# **(5370)** team member => bartender => bartender/server
#
# 		Naive Bayes: bartender
# 		fasttext: team member
#
# **(5377)** vice president => teacher => owner
#
# 		Naive Bayes: president
# 		fasttext: teacher
#
# **(5408)** sales representative => sales representative => account representative => branch manager => sales representative => account executive => retired
#
# 		Naive Bayes: sales representative
# 		fasttext: account executive
#
# **(5445)** operations manager => operations manager => sales manager => director of operations
#
# 		Naive Bayes: operations manager
# 		fasttext: sales manager
#
# **(5511)** sales associate => computer technician => network administrator
#
# 		Naive Bayes: sales associate
# 		fasttext: customer service representative
#
# **(5520)** accounts receivable clerk => bookkeeper => senior accountant
#
# 		Naive Bayes: bookkeeper
# 		fasttext: accounts receivable clerk
#
# **(5523)** design engineer => manufacturing engineer => engineer
#
# 		Naive Bayes: design engineer
# 		fasttext: project engineer
#
# **(5540)** bookkeeper => accounting clerk => accounting clerk => accounting assistant
#
# 		Naive Bayes: bookkeeper
# 		fasttext: accounting clerk
#
# **(5548)** co founder => sales associate => legal assistant
#
# 		Naive Bayes: sales associate
# 		fasttext: marketing assistant
#
# **(5554)** freelancer designer => senior designer => art director
#
# 		Naive Bayes: graphic designer
# 		fasttext: designer
#
# **(5557)** sales => sales consultant => independent contractor
#
# 		Naive Bayes: sales
# 		fasttext: sales consultant
#
# **(5558)** instructor => supervisor => volunteer
#
# 		Naive Bayes: supervisor
# 		fasttext: manager
#
# **(5589)** partner => lawyer => president => principal
#
# 		Naive Bayes: partner
# 		fasttext: president
#
# **(5593)** intern => president => senior accountant
#
# 		Naive Bayes: president
# 		fasttext: intern
#
# **(5615)** intern => operations supervisor => human resources intern => operations manager
#
# 		Naive Bayes: intern
# 		fasttext: human resources coordinator
#
# **(5648)** lecturer => software developer => systems analyst => senior analyst => project leader => developer
#
# 		Naive Bayes: systems analyst
# 		fasttext: project manager
#
# **(5662)** sales representative => accounting clerk => accountant
#
# 		Naive Bayes: sales representative
# 		fasttext: accounting clerk
#
# **(5674)** mechanical designer => sales manager => mechanical designer => project manager => service manager
#
# 		Naive Bayes: mechanical designer
# 		fasttext: project manager
#
# **(5720)** shipper/receiver => purchaser => warehouse manager => warehouse supervisor => shipper/receiver => warehouse supervisor
#
# 		Naive Bayes: warehouse manager
# 		fasttext: shipper/receiver
#
# **(5729)** owner => marketing director => marketing manager => president
#
# 		Naive Bayes: owner
# 		fasttext: marketing manager
#
# **(5777)** trainee => office manager => project manager
#
# 		Naive Bayes: office manager
# 		fasttext: volunteer
#
# **(5785)** vice president finance => accounting assistant => accountant
#
# 		Naive Bayes: chief finance officer
# 		fasttext: bookkeeper
#
# **(5786)** sales representative => brand ambassador => customer service representative
#
# 		Naive Bayes: sales representative
# 		fasttext: sales associate
#
# **(5791)** general laborer => project coordinator => project engineer
#
# 		Naive Bayes: project coordinator
# 		fasttext: project manager
#
# **(5805)** peer tutor => cashier => product manager
#
# 		Naive Bayes: cashier
# 		fasttext: volunteer
#
# **(5807)** sales assistant => research assistant => barista => coordinator
#
# 		Naive Bayes: research assistant
# 		fasttext: teaching assistant
#
# **(5878)** account representative => sales executive => account director => account manager
#
# 		Naive Bayes: account executive
# 		fasttext: director of marketing
#
# **(5902)** sales => president => sales manager => business development manager
#
# 		Naive Bayes: president
# 		fasttext: sales
#
# **(5907)** accountant => manager => president
#
# 		Naive Bayes: manager
# 		fasttext: senior manager
#
# **(5914)** administrative assistant => cashier => server
#
# 		Naive Bayes: administrative assistant
# 		fasttext: sales associate
#
# **(5919)** manager => accounting assistant => administrative assistant
#
# 		Naive Bayes: manager
# 		fasttext: accounting assistant
#
# **(5928)** customer service representative => accounting assistant => legal assistant
#
# 		Naive Bayes: customer service representative
# 		fasttext: bookkeeper
#
# **(5957)** bookkeeper => office manager => legal assistant => administrative assistant
#
# 		Naive Bayes: bookkeeper
# 		fasttext: legal assistant
#
# **(5967)** account manager => sales representative => account executive
#
# 		Naive Bayes: account manager
# 		fasttext: sales representative
#
# **(5973)** senior project manager => volunteer coordinator => volunteer coordinator
#
# 		Naive Bayes: senior project manager
# 		fasttext: project coordinator
#
# **(5996)** staff accountant => owner => senior manager => principal
#
# 		Naive Bayes: partner
# 		fasttext: senior manager
#
# **(6044)** administrator => customer service => receptionist
#
# 		Naive Bayes: customer service
# 		fasttext: student
#
# **(6057)** esthetician => server => director => owner
#
# 		Naive Bayes: consultant
# 		fasttext: customer service representative
#
# **(6070)** waitress => key holder => store manager
#
# 		Naive Bayes: waitress
# 		fasttext: sales associate
#
# **(6119)** information technology consultant => information technology consultant => information technology manager => information technology manager
#
# 		Naive Bayes: information technology consultant
# 		fasttext: owner
#
# **(6220)** human resources assistant => human resources generalist => independent consultant
#
# 		Naive Bayes: human resources generalist
# 		fasttext: human resources manager
#
# **(6227)** system analyst => management trainee => software engineer
#
# 		Naive Bayes: system analyst
# 		fasttext: software developer
#
# **(6249)** plant manager => operations manager => vice president
#
# 		Naive Bayes: operations manager
# 		fasttext: plant manager
#
# **(6284)** sales associate => engineering intern => coop student => intern
#
# 		Naive Bayes: research assistant
# 		fasttext: coop student
#
# **(6294)** territory manager => territory manager => sales => sales => delivery driver
#
# 		Naive Bayes: territory manager
# 		fasttext: sales
#
# **(6298)** general laborer => server => server => esthetician => cashier
#
# 		Naive Bayes: server
# 		fasttext: customer service representative
#
# **(6305)** intern => research assistant => software engineer
#
# 		Naive Bayes: research assistant
# 		fasttext: teaching assistant
#
# **(6309)** graduate teaching assistant => co founder => research associate
#
# 		Naive Bayes: co founder
# 		fasttext: sessional instructor
#
# **(6327)** volunteer => coop student => cashier
#
# 		Naive Bayes: volunteer
# 		fasttext: coop student
#
# **(6339)** cashier/customer service => cashier => office assistant
#
# 		Naive Bayes: cashier
# 		fasttext: cashier/customer service
#
# **(6344)** supervisor => construction manager => construction manager
#
# 		Naive Bayes: supervisor
# 		fasttext: project manager
#
# **(6345)** manager => associate => volunteer
#
# 		Naive Bayes: partner
# 		fasttext: associate
#
# **(6370)** consultant => senior consultant => principal consultant
#
# 		Naive Bayes: senior consultant
# 		fasttext: manager
#
# **(6371)** research assistant => executive director => senior consultant => director
#
# 		Naive Bayes: consultant
# 		fasttext: senior consultant
#
# **(6436)** lecturer => assistant professor => postdoctoral fellow => teacher => animator
#
# 		Naive Bayes: associate professor
# 		fasttext: lecturer
#
# **(6442)** accounting assistant => sales representative => junior accountant => staff accountant => accounting technician
#
# 		Naive Bayes: accountant
# 		fasttext: staff accountant
#
# **(6445)** volunteer => sales consultant => customer service
#
# 		Naive Bayes: sales associate
# 		fasttext: customer service representative
#
# **(6491)** executive assistant => system analyst => program coordinator
#
# 		Naive Bayes: executive assistant
# 		fasttext: administrator
#
# **(6520)** sales representative => vice president => vice president
#
# 		Naive Bayes: sales representative
# 		fasttext: president
#
# **(6568)** machinist => supervisor => supervisor => operations supervisor
#
# 		Naive Bayes: supervisor
# 		fasttext: machinist
#
# **(6593)** summer student => practicum student => research assistant
#
# 		Naive Bayes: lawyer
# 		fasttext: practicum student
#
# **(6605)** graphic designer => graphic designer => senior graphic designer => marketing manager
#
# 		Naive Bayes: graphic designer
# 		fasttext: senior graphic designer
#
# **(6607)** human resources assistant => human resources advisor => human resources advisor
#
# 		Naive Bayes: human resources manager
# 		fasttext: human resources consultant
#
# **(6620)** customer service => waiter => merchandiser
#
# 		Naive Bayes: customer service
# 		fasttext: sales representative
#
# **(6657)** senior business analyst => senior financial analyst => controller
#
# 		Naive Bayes: senior business analyst
# 		fasttext: senior financial analyst
#
# **(6665)** owner => owner => owner => sales manager => advisor => financial planner
#
# 		Naive Bayes: owner
# 		fasttext: sales manager
#
# **(6668)** supervisor => owner/operator => foreman
#
# 		Naive Bayes: owner
# 		fasttext: supervisor
#
# **(6690)** computer technician => research associate => technician
#
# 		Naive Bayes: research associate
# 		fasttext: consultant
#
# **(6703)** research assistant => engineer => director => general manager => general manager
#
# 		Naive Bayes: director
# 		fasttext: president
#
# **(6722)** owner => commercial account manager => realtor => owner/manager => owner
#
# 		Naive Bayes: realtor
# 		fasttext: real estate agent
#
# **(6731)** intern => contractor => software engineer => senior software engineer => contractor
#
# 		Naive Bayes: software engineer
# 		fasttext: software developer
#
# **(6737)** customer service representative => financial planner => realtor
#
# 		Naive Bayes: financial advisor
# 		fasttext: financial planner
#
# **(6744)** senior software developer => software developer => senior software engineer
#
# 		Naive Bayes: senior software developer
# 		fasttext: software developer
#
# **(6750)** operations manager => marketing analyst => president
#
# 		Naive Bayes: operations manager
# 		fasttext: account manager
#
# **(6799)** sales representative => inside sales representative => senior account executive
#
# 		Naive Bayes: sales representative
# 		fasttext: account manager
#
# **(6801)** senior accountant => manager => senior manager => principal
#
# 		Naive Bayes: senior manager
# 		fasttext: partner
#
# **(6808)** warehouse supervisor => inside sales representative => outside sales representative => inside sales representative => owner => inside sales representative
#
# 		Naive Bayes: outside sales representative
# 		fasttext: territory manager
#
# **(6845)** intern => intern => research assistant => research assistant => software engineer
#
# 		Naive Bayes: research assistant
# 		fasttext: teaching assistant
#
# **(6859)** manager => landscaper => coach
#
# 		Naive Bayes: manager
# 		fasttext: owner
#
# **(6860)** administrative assistant => graphic designer => student intern => designer
#
# 		Naive Bayes: administrative assistant
# 		fasttext: sales associate
#
# **(6868)** photographer => photographer => assistant => assistant => assistant => sales associate => assistant
#
# 		Naive Bayes: photographer
# 		fasttext: owner
#
# **(6874)** president & chief executive officer => marketing => personal trainer
#
# 		Naive Bayes: president & chief executive officer
# 		fasttext: president
#
# **(6888)** controller => owner => principal
#
# 		Naive Bayes: owner
# 		fasttext: controller
#
# **(6891)** owner operator => owner operator => area manager
#
# 		Naive Bayes: owner/operator
# 		fasttext: owner operator
#
# **(6904)** welder => sales => property manager
#
# 		Naive Bayes: welder
# 		fasttext: owner
#
# **(6907)** dishwasher => cashier/customer service => consultant
#
# 		Naive Bayes: cashier
# 		fasttext: cashier/customer service
#
# **(6910)** laboratory technician => lab technician => customer service representative => quality assurance
#
# 		Naive Bayes: laboratory technician
# 		fasttext: security officer
#
# **(6920)** communications coordinator => partner => volunteer coordinator
#
# 		Naive Bayes: partner
# 		fasttext: owner
#
# **(6933)** human resources assistant => human resources generalist => manager, human resources => director, human resources
#
# 		Naive Bayes: human resources manager
# 		fasttext: manager, human resources
#
# **(6944)** english teacher => teaching assistant => research assistant
#
# 		Naive Bayes: teaching assistant
# 		fasttext: english teacher
#
# **(7005)** developer => information technology consultant => senior developer
#
# 		Naive Bayes: software developer
# 		fasttext: information technology consultant
#
# **(7018)** administrative assistant => lifeguard => barista
#
# 		Naive Bayes: administrative assistant
# 		fasttext: lifeguard
#
# **(7023)** office clerk => student-at-law => customer service representative
#
# 		Naive Bayes: lawyer
# 		fasttext: associate
#
# **(7028)** assistant director => assistant director => executive director => managing director
#
# 		Naive Bayes: executive director
# 		fasttext: assistant director
#
# **(7038)** account coordinator => account coordinator => production manager => program manager
#
# 		Naive Bayes: account supervisor
# 		fasttext: account executive
#
# **(7055)** owner => general manager => manager => general manager
#
# 		Naive Bayes: owner
# 		fasttext: manager
#
# **(7063)** graduate research assistant => lecturer => lecturer => phd candidate
#
# 		Naive Bayes: assistant professor
# 		fasttext: lecturer
#
# **(7084)** president => co founder => co founder => co founder => co founder => vice president => vice president
#
# 		Naive Bayes: co founder
# 		fasttext: founder
#
# **(7092)** laborer => sales => child and youth worker => sales => child and youth worker => management trainee
#
# 		Naive Bayes: sales
# 		fasttext: child and youth worker
#
# **(7131)** auditor => financial analyst => accountant
#
# 		Naive Bayes: financial analyst
# 		fasttext: financial controller
#
# **(7133)** travel consultant => travel consultant => esthetician => administration => administrative assistant
#
# 		Naive Bayes: travel consultant
# 		fasttext: receptionist
#
# **(7141)** produce clerk => bartender => teaching assistant
#
# 		Naive Bayes: bartender
# 		fasttext: server
#
# **(7172)** analyst => director => associate => executive director
#
# 		Naive Bayes: director
# 		fasttext: associate
#
# **(7187)** member => designer => sales associate
#
# 		Naive Bayes: owner
# 		fasttext: member
#
# **(7206)** private tutor => accounting clerk => sales associate
#
# 		Naive Bayes: accounting clerk
# 		fasttext: staff accountant
#
# **(7217)** software engineer => project engineer => technical lead => technical lead => application developer => technical lead
#
# 		Naive Bayes: senior software engineer
# 		fasttext: software developer
#
# **(7281)** area manager => national account manager => national account manager
#
# 		Naive Bayes: sales manager
# 		fasttext: account executive
#
# **(7285)** shift supervisor => junior accountant => accountant => controller => teaching assistant => bookkeeper => controller
#
# 		Naive Bayes: accountant
# 		fasttext: bookkeeper
#
# **(7286)** president => owner => sales manager
#
# 		Naive Bayes: president
# 		fasttext: owner
#
# **(7383)** sales associate => research assistant => teaching assistant => teaching assistant => research assistant => sessional lecturer
#
# 		Naive Bayes: research assistant
# 		fasttext: teaching assistant
#
# **(7395)** store manager => manager => store manager => manager => district sales manager => district sales manager => district sales manager => general manager => financial services representative
#
# 		Naive Bayes: district manager
# 		fasttext: district sales manager
#
# **(7430)** financial controller => financial controller => owner => sales representative
#
# 		Naive Bayes: financial controller
# 		fasttext: director of finance
#
# **(7440)** merchandiser => chef => copywriter => landscaper
#
# 		Naive Bayes: chef
# 		fasttext: sales representative
#
# **(7458)** server => human resources consultant => hostess
#
# 		Naive Bayes: server
# 		fasttext: human resources assistant
#
# **(7460)** information technology consultant => technical analyst => system administrator
#
# 		Naive Bayes: information technology consultant
# 		fasttext: project manager
#
# **(7482)** key holder => research assistant => human resources administrator
#
# 		Naive Bayes: research assistant
# 		fasttext: sales associate
#
# **(7487)** shift manager => personal trainer => server/bartender => personal trainer => research assistant
#
# 		Naive Bayes: personal trainer
# 		fasttext: sales representative
#
# ...
#
# 		Naive Bayes: sales representative
# 		fasttext: research technician
#
# **(13602)** legal assistant => assistant => receptionist
#
# 		Naive Bayes: legal assistant
# 		fasttext: executive assistant
#
# **(13694)** customer service associate => management trainee => financial services representative => customer service representative => independent consultant
#
# 		Naive Bayes: financial advisor
# 		fasttext: financial services representative
#
# **(13708)** customer service representative => camp counsellor => child and youth worker
#
# 		Naive Bayes: customer service representative
# 		fasttext: sales associate
#
# **(13720)** machine operator => general laborer => sales representative
#
# 		Naive Bayes: machine operator
# 		fasttext: student
#
# **(13819)** cashier => student teacher => material handler => student teacher => student teacher => program coordinator => occasional teacher
#
# 		Naive Bayes: student teacher
# 		fasttext: substitute teacher
#
# **(13836)** developer => java developer => developer => senior software developer
#
# 		Naive Bayes: software developer
# 		fasttext: developer
#
# **(13851)** production worker => production worker => driver => truck driver => owner/operator
#
# 		Naive Bayes: truck driver
# 		fasttext: driver
#
# **(13856)** customer service representative => customer service representative => human resources intern => human resources coordinator
#
# 		Naive Bayes: customer service representative
# 		fasttext: human resources assistant
#
# **(13870)** marketing assistant => sales associate => brand ambassador => account executive
#
# 		Naive Bayes: customer service representative
# 		fasttext: administrative assistant
#
# **(13872)** administrative assistant => shift manager => labourer => equipment operator
#
# 		Naive Bayes: administrative assistant
# 		fasttext: sales associate
#
# **(13947)** administrative assistant => business manager => business manager => business manager => business manager => business manager => business manager => financial services manager => owner => author
#
# 		Naive Bayes: business manager
# 		fasttext: owner
#
# **(13955)** server => receptionist => sales representative => receptionist
#
# 		Naive Bayes: server
# 		fasttext: sales representative
#
# **(13956)** financial services representative => financial planner => sales representative
#
# 		Naive Bayes: financial advisor
# 		fasttext: regional sales manager
#
# **(13986)** software developer => software engineer => engineer
#
# 		Naive Bayes: software developer
# 		fasttext: software engineer
#
# **(14007)** human resources => human resources manager => assistant store manager => owner
#
# 		Naive Bayes: human resources manager
# 		fasttext: store manager
#
# **(14021)** human resources assistant => human resources consultant => human resources advisor
#
# 		Naive Bayes: human resources manager
# 		fasttext: human resources consultant
#
# **(14023)** administrative assistant => cashier => grocery clerk
#
# 		Naive Bayes: administrative assistant
# 		fasttext: sales associate
#
# **(14034)** camp counsellor => barista => customer service representative => intern
#
# 		Naive Bayes: customer service representative
# 		fasttext: sales associate
#
# **(14083)** receptionist => operations manager => service advisor
#
# 		Naive Bayes: administrative assistant
# 		fasttext: operations manager
#
# **(14097)** coordinator => coordinator => brand ambassador => cashier/customer service
#
# 		Naive Bayes: coordinator
# 		fasttext: sales representative
#
# **(14144)** controller => owner => instructor
#
# 		Naive Bayes: owner
# 		fasttext: controller
#
# **(14150)** accounting manager => vice president finance => chief operating officer
#
# 		Naive Bayes: controller
# 		fasttext: vice president finance
#
# **(14169)** sales => human resources advisor => human resources business partner
#
# 		Naive Bayes: sales
# 		fasttext: owner
#
# **(14171)** production supervisor => operations manager => assistant manager
#
# 		Naive Bayes: operations manager
# 		fasttext: plant manager
#
# **(14199)** sales => owner => owner/operator => sales
#
# 		Naive Bayes: owner
# 		fasttext: owner/operator
#
# **(14229)** coop student => coop student => coop student => coop student => research assistant => research assistant
#
# 		Naive Bayes: coop student
# 		fasttext: teaching assistant
#
# **(14231)** real estate agent => director => real estate agent
#
# 		Naive Bayes: director
# 		fasttext: owner
#
# **(14265)** equipment operator => engineer in training => project coordinator
#
# 		Naive Bayes: equipment operator
# 		fasttext: project engineer
#
# **(14267)** administrative assistant => customer service representative => human resources intern
#
# 		Naive Bayes: administrative assistant
# 		fasttext: customer service representative
#
# **(14290)** controller => owner => senior consultant
#
# 		Naive Bayes: owner
# 		fasttext: controller
#
# **(14296)** realtor => human resources administrator => project coordinator => project manager
#
# 		Naive Bayes: realtor
# 		fasttext: project coordinator
#
# **(14338)** project manager => managing director => technical lead => chief technology officer
#
# 		Naive Bayes: project manager
# 		fasttext: president
#
# **(14344)** supervisor => clerk => superintendent
#
# 		Naive Bayes: supervisor
# 		fasttext: server
#
# **(14372)** private tutor => tutor => office clerk
#
# 		Naive Bayes: research assistant
# 		fasttext: teaching assistant
#
# **(14374)** receptionist => customer service => brand ambassador
#
# 		Naive Bayes: receptionist
# 		fasttext: administrative assistant
#
# **(14378)** customer service representative => teaching assistant => translator
#
# 		Naive Bayes: customer service representative
# 		fasttext: teaching assistant
#
# **(14411)** owner/operator => customer service => sales associate
#
# 		Naive Bayes: owner/operator
# 		fasttext: customer service
#
# **(14427)** associate => store manager => sales consultant
#
# 		Naive Bayes: manager
# 		fasttext: store manager
#
# **(14449)** information technology technician => information technology technician => information technology technician => information technology technician => system administrator => information technology consultant => system administrator
#
# 		Naive Bayes: information technology technician
# 		fasttext: information technology consultant
#
# **(14479)** brand ambassador => teaching assistant => software developer => brand ambassador
#
# 		Naive Bayes: software developer
# 		fasttext: teaching assistant
#
# **(14488)** controller => director => information technology manager => staff accountant
#
# 		Naive Bayes: president
# 		fasttext: director
#
# **(14501)** engineer => project assistant => labourer
#
# 		Naive Bayes: project manager
# 		fasttext: project coordinator
#
# **(14541)** regional sales manager => account manager => account executive => owner => managing partner
#
# 		Naive Bayes: account executive
# 		fasttext: owner
#
# **(14554)** software engineer => software engineer => senior software engineer => system analyst
#
# 		Naive Bayes: software engineer
# 		fasttext: senior software engineer
#
# **(14558)** owner/operator => plant manager => store manager
#
# 		Naive Bayes: operations manager
# 		fasttext: owner
#
# **(14603)** manager => supervisor => lead hand => administrative assistant => administrative assistant
#
# 		Naive Bayes: manager
# 		fasttext: supervisor
#
# **(14621)** technical support => web developer => web developer => web developer => web developer => web developer => senior developer => senior engineer
#
# 		Naive Bayes: web developer
# 		fasttext: software developer
#
# **(14650)** senior manager => senior manager => director => partner => president & chief executive officer => senior vice president
#
# 		Naive Bayes: partner
# 		fasttext: director
#
# **(14653)** sales representative => sales representative => director => chief executive officer => director
#
# 		Naive Bayes: sales representative
# 		fasttext: chief executive officer
#
# **(14663)** office administrator => data entry clerk => assistant manager
#
# 		Naive Bayes: office administrator
# 		fasttext: administrative assistant
#
# **(14682)** team lead => business development => office administrator
#
# 		Naive Bayes: business analyst
# 		fasttext: business development
#
# **(14707)** senior accountant => treasurer => controller
#
# 		Naive Bayes: senior accountant
# 		fasttext: accountant
#
# **(14728)** millwright => apprentice electrician => electrician
#
# 		Naive Bayes: millwright
# 		fasttext: foreman
#
# **(14733)** mentor => receptionist => receptionist => receptionist => tutor
#
# 		Naive Bayes: receptionist
# 		fasttext: sales associate
#
# **(14773)** network administrator => information technology technician => network administrator => information technology manager
#
# 		Naive Bayes: network administrator
# 		fasttext: network engineer
#
# **(14775)** inside sales representative => outside sales representative => territory manager
#
# 		Naive Bayes: outside sales representative
# 		fasttext: account manager
#
# **(14819)** server => customer service representative => inside sales => territory sales manager
#
# 		Naive Bayes: customer service representative
# 		fasttext: sales
#
# **(14841)** associate => financial analyst => assistant controller => senior associate
#
# 		Naive Bayes: senior financial analyst
# 		fasttext: controller
#
# **(14845)** executive assistant => human resources => human resources
#
# 		Naive Bayes: executive assistant
# 		fasttext: human resources generalist
#
# **(14847)** teaching assistant => office administrator => office administrator => management trainee => marketing coordinator
#
# 		Naive Bayes: office administrator
# 		fasttext: assistant manager
#
# **(14874)** personal trainer => data analyst => brand ambassador => marketing coordinator => consultant
#
# 		Naive Bayes: personal trainer
# 		fasttext: marketing manager
#
# **(14938)** production engineer => process engineer => production engineer => project manager
#
# 		Naive Bayes: process engineer
# 		fasttext: production engineer
#
# **(14959)** sales manager => sales manager => financial services manager => director of finance
#
# 		Naive Bayes: sales manager
# 		fasttext: financial services manager
#
# **(14982)** program assistant => summer student => summer student => accountant
#
# 		Naive Bayes: associate
# 		fasttext: summer student
#
# **(15008)** account manager => regional sales manager => key account manager
#
# 		Naive Bayes: account manager
# 		fasttext: regional sales manager
#
# **(15012)** quality engineer => owner => general manager => operations manager
#
# 		Naive Bayes: owner
# 		fasttext: general manager
#
# **(15041)** student teacher => student teacher => intern
#
# 		Naive Bayes: teacher
# 		fasttext: student teacher
#
# **(15052)** manager => branch manager => department manager => senior consultant
#
# 		Naive Bayes: manager
# 		fasttext: store manager
#
# **(15105)** associate => partner => board of directors => board of directors => president => board of directors
#
# 		Naive Bayes: partner
# 		fasttext: lawyer
#
# **(15162)** administrative assistant => assistant manager => manager
#
# 		Naive Bayes: administrative assistant
# 		fasttext: assistant manager
#
# **(15178)** owner => designer => project manager => account manager
#
# 		Naive Bayes: owner
# 		fasttext: project manager
#
# **(15187)** trainee => marketing intern => operations manager
#
# 		Naive Bayes: intern
# 		fasttext: sales associate
#
# **(15217)** information technology project manager => technical analyst => information technology project manager
#
# 		Naive Bayes: project manager
# 		fasttext: business analyst
#
# **(15230)** administrative assistant => front desk agent => customer service representative
#
# 		Naive Bayes: administrative assistant
# 		fasttext: front desk agent
#
# **(15235)** financial analyst => financial analyst => senior analyst
#
# 		Naive Bayes: financial analyst
# 		fasttext: senior financial analyst
#
# **(15237)** senior systems analyst => senior systems analyst => president and chief executive officer
#
# 		Naive Bayes: senior systems analyst
# 		fasttext: senior business analyst
#
# **(15290)** administration => human resources manager => human resources consultant => real estate agent
#
# 		Naive Bayes: human resources manager
# 		fasttext: human resources consultant
#
# **(15330)** accountant => accountant => financial analyst => senior accountant
#
# 		Naive Bayes: accountant
# 		fasttext: financial analyst
#
# **(15403)** manager => sales representative => marketing coordinator => supervisor
#
# 		Naive Bayes: sales representative
# 		fasttext: account manager
#
# **(15418)** retail sales associate => cashier => retail sales associate
#
# 		Naive Bayes: cashier
# 		fasttext: sales associate
#
# **(15455)** cashier => technical support => receptionist => accountant
#
# 		Naive Bayes: receptionist
# 		fasttext: administrative assistant
#
# **(15499)** district sales manager => sales manager => business manager
#
# 		Naive Bayes: sales manager
# 		fasttext: general manager
#
# **(15526)** intern => crew member => security officer => crew member
#
# 		Naive Bayes: intern
# 		fasttext: sales associate
#
# **(15539)** programmer analyst => programmer/analyst => consultant => member
#
# 		Naive Bayes: programmer analyst
# 		fasttext: consultant
#
# **(15571)** administrator => information technology specialist => financial planner => financial advisor => director
#
# 		Naive Bayes: financial planner
# 		fasttext: financial advisor
#
# **(15595)** designer => engineer => project engineer
#
# 		Naive Bayes: designer
# 		fasttext: engineer
#
# **(15613)** pipefitter => foreman => supervisor
#
# 		Naive Bayes: pipefitter
# 		fasttext: foreman
#
# **(15634)** manufacturing engineer => engineer => financial analyst
#
# 		Naive Bayes: engineer
# 		fasttext: engineering manager
#
# **(15637)** accounting clerk => sales => realtor
#
# 		Naive Bayes: owner
# 		fasttext: office assistant
#
# **(15652)** lecturer => lecturer => phd student => teaching assistant => research assistant
#
# 		Naive Bayes: postdoctoral fellow
# 		fasttext: teaching assistant
#
# **(15672)** financial services representative => office coordinator => buyer
#
# 		Naive Bayes: financial advisor
# 		fasttext: administrator
#
# **(15675)** teacher => caregiver => supervisor => team member => teacher
#
# 		Naive Bayes: supervisor
# 		fasttext: shift manager
#
# **(15679)** administrative assistant => teaching assistant => co owner
#
# 		Naive Bayes: administrative assistant
# 		fasttext: research assistant
#
# **(15711)** sales associate => manager => server
#
# 		Naive Bayes: manager
# 		fasttext: sales associate
#
# **(15727)** coop student => photographer => photographer
#
# 		Naive Bayes: sales associate
# 		fasttext: coop student
#
# **(15783)** director => director => project manager => program manager => owner => program manager => project director
#
# 		Naive Bayes: director
# 		fasttext: project manager
#
# **(15801)** marketing director => marketing manager => director of marketing
#
# 		Naive Bayes: marketing director
# 		fasttext: marketing manager
#
# **(15832)** outside sales representative => sales representative => assistant store manager => account manager
#
# 		Naive Bayes: sales representative
# 		fasttext: store manager
#
# **(15884)** software developer => software engineer => senior software engineer
#
# 		Naive Bayes: software developer
# 		fasttext: software engineer
#
# **(15912)** general laborer => sales associate => server
#
# 		Naive Bayes: sales associate
# 		fasttext: general laborer
#
# **(15916)** producer => producer => owner => chief executive officer
#
# 		Naive Bayes: producer
# 		fasttext: owner
#
# **(15919)** data entry => technical writer => administrative assistant => data analyst
#
# 		Naive Bayes: administrative assistant
# 		fasttext: accounting clerk
#
# **(15925)** customer service representative => teacher => customer service representative => junior accountant => general accountant
#
# 		Naive Bayes: customer service representative
# 		fasttext: senior accountant
#
# **(15947)** senior manager => senior manager => sales associate
#
# 		Naive Bayes: partner
# 		fasttext: senior manager
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-364-7ed561b969cb> in <module>()
#       4                         diff.fasttext_pred.values):
#       5
# ----> 6     if is_most_common['nb'][i] or is_most_common['fasttext'][i]:
#       7         continue
#       8     if t != nb and t != ft:
#
# IndexError: list index out of range

# %%
diff = pred_df[pred_df['fasttext_pred'] != pred_df['target']]

# %%
plt.rcParams['figure.figsize'] = 15, 3
plt.rcParams['figure.dpi'] = 180

plt.plot([t[0] for t in data],[t[1] for t in data])
for target in set(diff.nb_pred.values):
    plt.axvspan(target,target, color='red', alpha=0.5)

# %%
plt.rcParams['figure.figsize'] = 15, 3
plt.rcParams['figure.dpi'] = 180

plt.plot([t[0] for t in data],[t[1] for t in data])
for target in set(diff.fasttext_pred.values):
    plt.axvspan(target,target, color='red', alpha=0.5)

# %%
sorted_data = sorted(data, key=lambda t: t[1], reverse=True)

# %%
mapping = bidict({t[0]: i for i, t in enumerate(sorted_data)})

# %%
freqs = [t[1] for t in sorted_data]

# %%
freqs[100]
# Out:
# 0.0022321196831428247

# %%
plt.plot(range(len(freqs)), freqs)

# %%
errors = pred_df[pred_df['nb_pred'] != pred_df['target']]
correct = pred_df[pred_df['nb_pred'] == pred_df['target']]

plt.plot(range(len(freqs)), freqs)
for target in set(errors.nb_pred.values):
    plt.axvspan(mapping[target],mapping[target], color='red', alpha=0.5)
for target in set(correct.nb_pred.values):
    plt.axvspan(mapping[target],mapping[target], color='green', alpha=0.5)

# %%
errors = pred_df[pred_df['fasttext_pred'] != pred_df['target']]
correct = pred_df[pred_df['fasttext_pred'] == pred_df['target']]

plt.plot(range(len(freqs)), freqs)
for target in set(errors.fasttext_pred.values):
    plt.axvspan(mapping[target],mapping[target], color='red', alpha=0.5)
for target in set(correct.nb_pred.values):
    plt.axvspan(mapping[target],mapping[target], color='green', alpha=0.5)

# %%
most = [mapping.inv[i] for i in list(range(0,100))]
least = [mapping.inv[i] for i in list(range(100,len(freqs)))]

# %%
cutoff = 100

most_freq = pred_df[pred_df['target'].isin(most)]
least_freq = pred_df[pred_df['target'].isin(least)]

# %%
len(most_freq)
# Out:
# 15452

# %%
len(pred_df[pred_df.target == pred_df.fasttext_pred])/len(pred_df)
# Out:
# 0.3372923588039867

# %%
most_freq_acc = dict()
least_freq_acc = dict()

for model in models:
    most_freq_acc[model] = len(most_freq[most_freq.target == most_freq[f'{model}_pred']])/len(most_freq)
    least_freq_acc[model] = len(least_freq[least_freq.target == least_freq[f'{model}_pred']])/len(least_freq)

# %%
most_freq_acc
# Out:
# {'bigram': 0.3796272327206834,
#  'fasttext': 0.3857753041677453,
#  'nb': 0.38428682371214085}

# %%
least_freq_acc
# Out:
# {'bigram': 0.29160871580899395,
#  'fasttext': 0.2504636068613815,
#  'nb': 0.21407046824293}
